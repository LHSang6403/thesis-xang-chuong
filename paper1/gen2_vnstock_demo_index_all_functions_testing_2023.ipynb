# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/thinh-vu/vnstock/blob/beta/docs/gen2_vnstock_demo_index_all_functions_testing_2023.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # I. Giới thiệu

# %% [markdown]
# Bạn có thể tham khảo video hướng dẫn tổng quan về vnstock để bắt đầu dễ dàng [tại đây](https://www.youtube.com/watch?v=6kP2TTtEY9Y&ab_channel=LEarnAnything)

# %%
# Cài đặt thư viện vnstock từ Pypi - bản ổn định | Install vnstock from Pypi - stable version
#pip install -U vnstock
# Out:
# Requirement already satisfied: vnstock in d:\pyprojects\anaconda\lib\site-packages (0.2.8.6)

# %%
from vnstock import * #import all functions

# %% [markdown]
# # II. Các nhóm hàm tính toán

# %% [markdown]
# Vi: Thu gọn toàn bộ code ở mục này, chạy code một lần duy nhất, nếu code chạy đến cuối file thành công thì thư viện vnstock hoạt động bình thường. **Google Colab được chọn là môi trường tiêu chuẩn để sử dụng vnstock và debug lỗi.**
#
# En: `Collapse all the code in this section, run the code only once, if the code runs to the end of the file successfully, then the vnstock library will work normally in most cases`

# %% [markdown]
# ## 2.1. Liệt kê cổ phiếu niêm yết

# %% [markdown]
# #### 📰 Danh sách cổ phiếu niêm yết
#
# Lưu ý: danh sách này không phản ánh dữ liệu theo thời gian thực mà được cập nhật hàng tháng.

# %% [markdown]
# ##### Chế độ offline

# %%
listing_companies()
# Out:
#      ticker comGroupCode                                          organName  \
# 0       SSI         HOSE                    Công ty Cổ phần Chứng khoán SSI
# 1       BCM         HOSE  Tổng Công ty Đầu tư và Phát triển Công nghiệp ...
# 2       VHM         HOSE                           Công ty Cổ phần Vinhomes
# 3       VIC         HOSE                     Tập đoàn Vingroup - Công ty CP
# 4       VRE         HOSE                      Công ty Cổ phần Vincom Retail
# ...     ...          ...                                                ...
# 1602    SDK        UPCOM                   Công ty Cổ phần Cơ khí Luyện Kim
# 1603    SRF         HOSE                          Công ty Cổ phần Searefico
# 1604    UEM        UPCOM        Công ty Cổ phần Cơ điện Uông Bí - Vinacomin
# 1605    VEA        UPCOM  Tổng Công ty Máy động lực và Máy nông nghiệp V...
# 1606    VES        UPCOM  Công ty Cổ phần Đầu tư và Xây dựng Điện MÊ CA ...
#
#                    organShortName organTypeCode comTypeCode  \
# 0                 Chứng khoán SSI            DN          CK
# 1                     Becamex IDC            DN          CT
# 2                        Vinhomes            DN          CT
# 3                        VinGroup            DN          CT
# 4                   Vincom Retail            DN          CT
# ...                           ...           ...         ...
# 1602             Cơ khí Luyện Kim            DN          CT
# 1603                    SEAREFICO            DN          CT
# 1604  Cơ điện Uông Bí - Vinacomin            DN          CT
# 1605       Máy động lực và Máy NN            DN          CT
# 1606                  MÊ CA VNECO            DN          CT
#
#                    icbName                                        icbNamePath  \
# 0     Môi giới chứng khoán  Tài chính/Dịch vụ tài chính/Dịch vụ tài chính/...
# 1             Bất động sản   Tài chính/Bất động sản/Bất động sản/Bất động sản
# 2             Bất động sản   Tài chính/Bất động sản/Bất động sản/Bất động sản
# 3             Bất động sản   Tài chính/Bất động sản/Bất động sản/Bất động sản
# 4             Bất động sản   Tài chính/Bất động sản/Bất động sản/Bất động sản
# ...                    ...                                                ...
# 1602       Máy công nghiệp  Công nghiệp/Hàng & Dịch vụ Công nghiệp/Công ng...
# 1603       Máy công nghiệp  Công nghiệp/Hàng & Dịch vụ Công nghiệp/Công ng...
# 1604       Máy công nghiệp  Công nghiệp/Hàng & Dịch vụ Công nghiệp/Công ng...
# 1605       Máy công nghiệp  Công nghiệp/Hàng & Dịch vụ Công nghiệp/Công ng...
# 1606       Máy công nghiệp  Công nghiệp/Hàng & Dịch vụ Công nghiệp/Công ng...
#
#            sector                    industry  ... VNCOND VNCONS  VNENE  \
# 0       Tài chính           Dịch vụ tài chính  ...  False  False  False
# 1       Tài chính                Bất động sản  ...  False  False  False
# 2       Tài chính                Bất động sản  ...  False  False  False
# 3       Tài chính                Bất động sản  ...  False  False  False
# 4       Tài chính                Bất động sản  ...  False  False  False
# ...           ...                         ...  ...    ...    ...    ...
# 1602  Công nghiệp  Hàng & Dịch vụ Công nghiệp  ...  False  False  False
# 1603  Công nghiệp  Hàng & Dịch vụ Công nghiệp  ...  False  False  False
# 1604  Công nghiệp  Hàng & Dịch vụ Công nghiệp  ...  False  False  False
# 1605  Công nghiệp  Hàng & Dịch vụ Công nghiệp  ...  False  False  False
# 1606  Công nghiệp  Hàng & Dịch vụ Công nghiệp  ...  False  False  False
#
#       VNFIN  VNHEAL  VNIND   VNIT  VNMAT  VNREAL  VNUTI
# 0      True   False  False  False  False   False  False
# 1     False   False  False  False  False    True  False
# 2     False   False  False  False  False    True  False
# 3     False   False  False  False  False    True  False
# 4     False   False  False  False  False    True  False
# ...     ...     ...    ...    ...    ...     ...    ...
# 1602  False   False  False  False  False   False  False
# 1603  False   False  False  False  False   False  False
# 1604  False   False  False  False  False   False  False
# 1605  False   False  False  False  False   False  False
# 1606  False   False  False  False  False   False  False
#
# [1607 rows x 35 columns]

# %% [markdown]
# ##### Chế độ online - nguồn Wifeed

# %%
listing_companies(live=True)
# Out:
#      ticker                                       organName  organTypeCode  \
# 0       A32                                         CTCP 32              1
# 1       AAA                          CTCP Nhựa An Phát Xanh              1
# 2       AAM                            CTCP Thủy sản MeKong              1
# 3       AAS                    CTCP Chứng khoán SmartInvest              4
# 4       AAT                CTCP Tập Đoàn Tiên Sơn Thanh Hóa              1
# ...     ...                                             ...            ...
# 1579    XPH                            CTCP Xà phòng Hà Nội              1
# 1580    YBC              CTCP Xi măng và Khoáng sản Yên Bái              1
# 1581    YBM             CTCP Khoáng sản Công nghiệp Yên Bái              1
# 1582    YEG                             CTCP Tập đoàn Yeah1              1
# 1583    YTC  CTCP Xuất nhập khẩu Y tế Thành phố Hồ Chí Minh              1
#
#      comGroupCode
# 0           UPCOM
# 1            HOSE
# 2            HOSE
# 3           UPCOM
# 4            HOSE
# ...           ...
# 1579        UPCOM
# 1580        UPCOM
# 1581         HOSE
# 1582         HOSE
# 1583        UPCOM
#
# [1584 rows x 4 columns]

# %% [markdown]
# ##### Chế độ online - nguồn SSI

# %%
listing_companies(live=True, source='SSI')
# Out:
# Total number of companies:  1605
#        organCode ticker comGroupCode icbCode organTypeCode comTypeCode  \
# 0     0104498100    VVS   UpcomIndex    3353            DN          CT
# 1     0109204756    HIO   UpcomIndex    7535            DN          CT
# 2     0304941312    XDC   UpcomIndex    2357            DN          CT
# 3     0313140100    SBG      VNINDEX    2727            DN          CT
# 4     0700519785    THM   UpcomIndex    3763            DN          CT
# ...          ...    ...          ...     ...           ...         ...
# 1600  XUANMINHHP    XMP   UpcomIndex    7535            DN          CT
# 1601         YBC    YBC   UpcomIndex    2353            DN          CT
# 1602        YBMC    YBM      VNINDEX    1775            DN          CT
# 1603     YEGCORP    YEG      VNINDEX    5553            DN          CT
# 1604       YTECO    YTC   UpcomIndex    4537            DN          CT
#
#                                               organName  \
# 0        Công ty Cổ phần Đầu tư Phát triển Máy Việt Nam
# 1                          Công ty Cổ Phần Helio Energy
# 2          Công ty Cổ phần Xây dựng Công trình Tân Cảng
# 3     Công ty Cổ Phần Tập Đoàn Cơ Khí Công Nghệ Cao ...
# 4                         Công ty Cổ phần Tứ Hải Hà Nam
# ...                                                 ...
# 1600                Công ty Cổ phần Thủy điện Xuân Minh
# 1601      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 1602     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 1603                     Công ty Cổ phần Tập đoàn Yeah1
# 1604  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
#
#                       organShortName
# 0     Đầu tư Phát triển Máy Việt Nam
# 1                       Helio Energy
# 2       Xây dựng Công trình Tân Cảng
# 3                     Siba Group Jsc
# 4                      Tứ Hải Hà Nam
# ...                              ...
# 1600             Thủy điện Xuân Minh
# 1601   Xi măng và Khoáng sản Yên Bái
# 1602           Khoáng sản CN Yên Bái
# 1603                  Tập đoàn Yeah1
# 1604                 XNK Y tế TP.HCM
#
# [1605 rows x 8 columns]

# %% [markdown]
# #### Danh sách mã chỉ số

# %%
indices_listing(lang='vi')
# Out:
#    comGroupCode parentComGroupCode  comGroupOrder
# 0       VNINDEX            VNINDEX              1
# 1      HNXIndex           HNXIndex              2
# 2          VN30            VNINDEX              2
# 3        VNCOND            VNINDEX              2
# 4         HNX30           HNXIndex              3
# 5    UpcomIndex         UpcomIndex              3
# 6         VN100            VNINDEX              3
# 7        VNCONS            VNINDEX              3
# 8         VNENE            VNINDEX              4
# 9         VNX50            VNINDEX              4
# 10        VNFIN            VNINDEX              5
# 11       VNHEAL            VNINDEX              6
# 12       VNXALL            VNINDEX              6
# 13        VNIND            VNINDEX              7
# 14         VNIT            VNINDEX              8
# 15        VNMAT            VNINDEX              9
# 16        VNSML            VNINDEX              9
# 17        VNMID            VNINDEX             10
# 18       VNREAL            VNINDEX             10
# 19        VNALL            VNINDEX             11
# 20        VNUTI            VNINDEX             11
# 21    VNDIAMOND            VNINDEX             12
# 22    VNFINLEAD            VNINDEX             13
# 23  VNFINSELECT            VNINDEX             14
# 24         VNSI            VNINDEX             17

# %% [markdown]
# ## 2.2. 💴 Phân tích cơ bản

# %% [markdown]
# ### Thông tin công ty niêm yết

# %% [markdown]
# #### Tổng quan

# %%
company_overview('CTS')
# Out:
#   ticker exchange           industry companyType  noShareholders  \
# 0    CTS     HOSE  Dịch vụ tài chính          CK            4031
#
#    foreignPercent  outstandingShare  issueShare establishedYear  noEmployees  \
# 0           0.014             148.7       148.7            2000          206
#
#    stockRating  deltaInWeek  deltaInMonth  deltaInYear  \
# 0          2.6       -0.006         0.178        1.872
#
#                 shortName          industryEn  industryID industryIDv2  \
# 0  Chứng khoán Vietinbank  Financial Services         300         8777
#
#               website
# 0  https://www.cts.vn

# %% [markdown]
# #### Thông tin công ty (Mới)

# %%
company_profile ('CTS')
# Out:
#      id                                        companyName ticker  \
# 0  None  Công ty Cổ phần Chứng khoán Ngân hàng Công thư...    CTS
#
#                                       companyProfile  \
# 0  Công ty Cổ phần Chứng khoán Ngân hàng Công thư...
#
#                                           historyDev companyPromise  \
# 0    2000: Tiền thân của công ty là Công ty TNHH ...           None
#
#                                         businessRisk  \
# 0    Số lượng các công ty chứng khoán ngày càng t...
#
#                                      keyDevelopments  \
# 0    Môi giới chứng khoán. Bảo lãnh phát hành chứ...
#
#                                   businessStrategies
# 0    Định hướng khai thác khách hàng lớn là các t...

# %% [markdown]
# #### Danh sách cổ đông (Mới)

# %%
company_large_shareholders (symbol='CTS')
# Out:
#   ticker                                        shareHolder  shareOwnPercent
# 0    CTS  Ngân hàng Thương mại Cổ phần Công thương Việt Nam           0.7564
# 1    CTS  Yurie Vietnam Securities Investment Trust (Stock)           0.0583
# 2    CTS                                         Lê Đức Thọ           0.0560
# 3    CTS                                      Chu Mạnh Hiền           0.0009
# 4    CTS                                               Khác           0.0001

# %% [markdown]
# #### Các chỉ số tài chính cơ bản (Mới)

# %%
company_fundamental_ratio (symbol='CTS', mode='simplify', missing_pct=0.8)
# Out:
#   ticker priceToEarning.top200AvgValue priceToEarning.industryAvgValue  \
# 0    CTS                          14.3                            25.9
#
#   valueBeforeEbitda.top200AvgValue valueBeforeEbitda.industryAvgValue  \
# 0                             12.4                               17.2
#
#   priceToBook.top200AvgValue priceToBook.industryAvgValue  \
# 0                        1.6                          1.4
#
#   dividend.top200AvgValue dividend.industryAvgValue roe.top200AvgValue  ...  \
# 0                       0                         0              0.094  ...
#
#   revenueOnAsset.top200AvgValue revenueOnAsset.industryAvgValue  \
# 0                           0.4                             0.2
#
#   ebitOnRevenue.top200AvgValue ebitOnRevenue.industryAvgValue  \
# 0                        0.156                          0.451
#
#   netDebtOnEbitda.top200AvgValue netDebtOnEbitda.industryAvgValue  \
# 0                            2.2                              1.4
#
#   netDebtOnEquity.top200AvgValue netDebtOnEquity.industryAvgValue  \
# 0                            0.6                              0.2
#
#   priceToSales.top200AvgValue priceToSales.industryAvgValue
# 0                           2                           5.8
#
# [1 rows x 59 columns]

# %% [markdown]
# #### Mức biến động giá cổ phiếu (Mới)

# %%
ticker_price_volatility (symbol='CTS')
# Out:
#   ticker  ticker_highestPrice  ticker_lowestPrice  ticker_highestPricePercent  \
# 0    CTS              32800.0              9630.0                      -0.177
#
#    ticker_lowestPricePercent
# 0                      1.804

# %% [markdown]
# #### Thông tin giao dịch nội bộ (Mới)

# %%
company_insider_deals (symbol='CTS', page_size=20, page=0)
# Out:
#    ticker dealAnnounceDate        dealMethod dealAction  dealQuantity  \
# 0     CTS       2020-12-28       Cổ đông lớn        Bán      -29000.0
# 1     CTS       2020-09-25       Cổ đông lớn        Bán      -60000.0
# 2     CTS       2018-08-16    Cổ đông nội bộ        Mua       92000.0
# 3     CTS       2018-07-09       Cổ đông lớn        Mua       30000.0
# 4     CTS       2018-04-20       Cổ đông lớn        Mua      152600.0
# 5     CTS       2017-06-21  Cổ đông sáng lập        Bán           0.0
# 6     CTS       2017-06-14    Cổ đông nội bộ        Bán     -125000.0
# 7     CTS       2017-05-17    Cổ đông nội bộ        Mua       25000.0
# 8     CTS       2016-09-09    Cổ đông nội bộ        Mua       35200.0
# 9     CTS       2014-05-21       Cổ đông lớn        Bán           0.0
# 10    CTS       2009-10-29    Cổ đông nội bộ        Bán       -6000.0
# 11    CTS       2009-10-13    Cổ đông nội bộ        Bán       -8000.0
# 12    CTS       2009-09-14    Cổ đông nội bộ        Mua        8000.0
# 13    CTS       2009-08-18    Cổ đông nội bộ        Mua        6000.0
#
#     dealPrice  dealRatio
# 0     10803.0      1.499
# 1      5373.0      4.025
# 2      6628.0      3.074
# 3      5625.0      3.800
# 4      8564.0      2.153
# 5      6491.0      3.160
# 6      6246.0      3.323
# 7      4943.0      4.462
# 8      3313.0      7.150
# 9         NaN        NaN
# 10        NaN        NaN
# 11        NaN        NaN
# 12        NaN        NaN
# 13        NaN        NaN

# %% [markdown]
# #### Danh sách công ty con, công ty liên kết (Mới)

# %%
company_subsidiaries_listing (symbol='CTS', page_size=100, page=0)
# Out:
#   ticker                                    subCompanyName  subOwnPercent
# 0    CTS                         Công ty Cổ phần Kiên Hùng          0.109
# 1    CTS                     Quỹ Đầu Tư Năng Động Việt Nam          0.062
# 2    CTS    Công ty Cổ phần Phát triển Nhà Bà Rịa Vũng Tàu          0.038
# 3    CTS            Công ty Cổ phần Than Hà Tu - Vinacomin          0.032
# 4    CTS   Công ty Cổ phần Chế biến Hàng Xuất khẩu Long An          0.018
# 5    CTS                               Công ty Cổ phần CMC          0.000
# 6    CTS       Công ty Cổ phần Đầu tư và Dịch vụ Khánh Hội          0.000
# 7    CTS   Công ty Cổ phần Nước giải khát Sanest Khánh Hòa          0.000
# 8    CTS  Công ty Cổ phần Nước Giải khát Yến sào Khánh Hòa          0.000

# %% [markdown]
# #### Ban lãnh đạo công ty (Mới)

# %%
company_officers (symbol='CTS', page_size=20, page=0)
# Out:
#    ticker           officerName               officerPosition  \
# 0     CTS            Lê Đức Thọ                          None
# 1     CTS         Chu Mạnh Hiền                          None
# 2     CTS      Nguyễn Thọ Phùng  Thành viên Hội đồng Quản trị
# 3     CTS      Nguyễn Thọ Phùng             Phó Tổng Giám đốc
# 16    CTS       Hồ Thị Thu Hiền  Thành viên Hội đồng Quản trị
# 14    CTS        Trần Phúc Vinh    Chủ tịch Hội đồng Quản trị
# 4     CTS          Cát Huy Long                          None
# 5     CTS      Nguyễn Văn Thành                          None
# 6     CTS       Phan Quốc Huỳnh                          None
# 7     CTS     Bùi Thị Thủy Ngân                          None
# 8     CTS     Nguyễn Thu Phương                          None
# 9     CTS        Nguyễn Thúy Hà                          None
# 10    CTS  Nguyễn Thị Thúy Hằng                          None
# 11    CTS   Hoàng Thị Thùy Linh                          None
# 12    CTS          Tô Giang Nam                          None
# 13    CTS        Phạm Ngọc Hiệp                          None
# 15    CTS          Đặng Anh Hào                          None
# 17    CTS  Nguyễn Thị Thùy Linh                          None
# 18    CTS           Đào Thị Yến                          None
# 19    CTS       Nguyễn Tuấn Anh                          None
#
#     officerOwnPercent
# 0              0.0560
# 1              0.0009
# 2              0.0001
# 3              0.0001
# 16             0.0000
# 14             0.0000
# 4              0.0000
# 5              0.0000
# 6              0.0000
# 7              0.0000
# 8              0.0000
# 9              0.0000
# 10             0.0000
# 11             0.0000
# 12             0.0000
# 13             0.0000
# 15             0.0000
# 17             0.0000
# 18             0.0000
# 19             0.0000

# %% [markdown]
# #### Thông tin sự kiện quyền (Mới)

# %%
company_events (symbol='CTS', page_size=15, page=0)
# Out:
#          id ticker    price  priceChange  priceChangeRatio  \
# 0   2563538    CTS  23100.0        100.0             0.004
# 1   2560965    CTS  13450.0       -350.0            -0.025
# 2   2560042    CTS  13200.0        350.0             0.027
# 3   2559520    CTS  17849.0        695.0             0.041
# 4   2559521    CTS  17849.0        695.0             0.041
# 5   2558433    CTS  13600.0      -1004.0            -0.069
# 6   2558110    CTS  19472.0        309.0             0.016
# 7   2557696    CTS  26793.0       -179.0            -0.007
# 8   2456431    CTS  25613.0        215.0             0.008
# 9   2365742    CTS  33626.0       -358.0            -0.011
# 10  1672724    CTS  11733.0       -358.0            -0.030
# 11  1328374    CTS   4150.0       -164.0            -0.038
# 12  1316831    CTS      NaN          NaN               NaN
# 13  1225529    CTS   6022.0        -13.0            -0.002
# 14  1255752    CTS   6393.0         64.0             0.010
#
#     priceChangeRatio1W  priceChangeRatio1M  \
# 0                0.034               0.222
# 1               -0.004              -0.022
# 2               -0.140              -0.292
# 3                0.050               0.309
# 4                0.050               0.309
# 5               -0.204              -0.475
# 6               -0.060              -0.263
# 7                0.027              -0.025
# 8               -0.020              -0.135
# 9                0.056               0.697
# 10               0.051               0.093
# 11              -0.079              -0.141
# 12                 NaN                 NaN
# 13              -0.009               0.048
# 14               0.047               0.011
#
#                                             eventName eventCode  \
# 0                 CTS - Tổ chức ĐHĐCĐ bất thường 2023      EGME
# 1                CTS - Tổ chức ĐHĐCĐ thường niên 2023      AGME
# 2          CTS - Niêm yết bổ sung 33,791,500 cổ phiếu       AIS
# 3    CTS - Phát hành cổ phiếu trả cổ tức tỷ lệ 21,96%       ISS
# 4         CTS - Phát hành cổ phiếu thưởng tỷ lệ 7,46%       ISS
# 5           CTS - Niêm yết bổ sung 8,510,235 cổ phiếu       AIS
# 6                 CTS - Tổ chức ĐHĐCĐ bất thường 2022      EGME
# 7        CTS - Phát hành cổ phiếu trả cổ tức tỷ lệ 8%       ISS
# 8                CTS - Tổ chức ĐHĐCĐ thường niên 2022      AGME
# 9   CTS - Tổ chức đại hội đồng cổ đông bất thường ...      EGME
# 10               CTS - Tổ chức ĐHĐCĐ thường niên 2021      AGME
# 11               CTS - Tổ chức ĐHĐCĐ thường niên 2020      AGME
# 12                             CTS - Mua cổ phiếu quỹ        TS
# 13  CTS - Trả cổ tức Cả năm, 2018 bằng tiền 1000 V...       DIV
# 14                             CTS - Mua cổ phiếu quỹ        TS
#
#              notifyDate             exerDate         regFinalDate  \
# 0   2023-07-14 00:00:00  2023-08-24 00:00:00  2023-07-31 00:00:00
# 1   2023-02-10 00:00:00  2023-03-27 00:00:00  2023-02-27 00:00:00
# 2   2022-10-12 00:00:00  2022-10-07 00:00:00  1753-01-01 00:00:00
# 3   2022-08-16 00:00:00  2022-08-24 00:00:00  2022-08-25 00:00:00
# 4   2022-08-16 00:00:00  2022-08-24 00:00:00  2022-08-25 00:00:00
# 5   2022-05-13 00:00:00  2022-05-23 00:00:00  1753-01-01 00:00:00
# 6   2022-04-29 00:00:00  2022-07-04 00:00:00  2022-06-03 00:00:00
# 7   2022-03-24 11:11:17  2022-03-28 00:00:00  2022-03-29 00:00:00
# 8   2022-02-15 00:00:00  2022-03-21 00:00:00  2022-02-21 00:00:00
# 9   2021-11-26 10:17:55  2022-01-10 00:00:00  2021-12-13 00:00:00
# 10  2021-03-16 00:00:00  2021-04-27 00:00:00  2021-03-30 00:00:00
# 11  2020-03-24 00:00:00  2020-04-27 00:00:00  2020-04-06 00:00:00
# 12  2020-02-08 00:00:00  2020-02-08 00:00:00                 None
# 13  2019-09-10 09:00:00  2019-09-27 00:00:00  2019-09-16 00:00:00
# 14  2019-04-08 00:00:00  2019-04-08 00:00:00                 None
#
#             exRigthDate                                          eventDesc  \
# 0   2023-07-28 00:00:00  <p>Công ty Cổ phần Chứng khoán Ngân hàng Công ...
# 1   2023-02-24 00:00:00  <p>Công ty Cổ phần Chứng khoán Ngân hàng Công ...
# 2   1753-01-01 00:00:00  <p>Công ty Cổ phần Chứng khoán Ngân hàng Công ...
# 3   2022-08-24 00:00:00  <p>Công ty Cổ phần Chứng khoán Ngân hàng Công ...
# 4   2022-08-24 00:00:00  <p>Công ty Cổ phần Chứng khoán Ngân hàng Công ...
# 5   1753-01-01 00:00:00  <p>Công ty Cổ phần Chứng khoán Ngân hàng Công ...
# 6   2022-06-02 00:00:00  <p>Công ty Cổ phần Chứng khoán Ngân hàng Công ...
# 7   2022-03-28 00:00:00  <DIV style="FONT-FAMILY: Arial; FONT-SIZE: 10p...
# 8   2022-02-18 00:00:00  <DIV style="FONT-FAMILY: Arial; FONT-SIZE: 10p...
# 9   2021-12-10 00:00:00  <DIV style="FONT-FAMILY: Arial; FONT-SIZE: 10p...
# 10  2021-03-29 00:00:00  <DIV style="FONT-FAMILY: Arial; FONT-SIZE: 10p...
# 11  2020-04-03 00:00:00  <DIV style="FONT-FAMILY: Arial; FONT-SIZE: 10p...
# 12                 None  CTS - Mua 17 cổ phiếu quỹ. Số cổ phiếu quỹ sau...
# 13  2019-09-13 00:00:00  <DIV style="FONT-FAMILY: Arial; FONT-SIZE: 10p...
# 14                 None                             CTS - Mua cổ phiếu quỹ
#
#                                             eventNote
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7
# 8
# 9    http://fiinpro.com/News/Detail/10150209?lang=...
# 10
# 11
# 12                                               None
# 13
# 14                                               None

# %% [markdown]
# #### Tin tức công ty (Mới)

# %%
company_news (symbol='CTS', page_size=15, page=0)
# Out:
#    ticker  price  priceChange  priceChangeRatio  priceChangeRatio1W  \
# 0     CTS  27300          900             0.034               0.058
# 1     CTS  25550          650             0.026               0.151
# 2     CTS  23300          200             0.009               0.201
# 3     CTS  20800        -1500            -0.067              -0.119
# 4     CTS  22300          600             0.028              -0.035
# 5     CTS  23300         -700            -0.029               0.004
# 6     CTS  32800          500             0.015               0.006
# 7     CTS  31450         -550            -0.017               0.052
# 8     CTS  26300          700             0.027               0.091
# 9     CTS  25600          250             0.010               0.056
# 10    CTS  25600          250             0.010               0.056
# 11    CTS  25000          900             0.037              -0.042
# 12    CTS  26100         -400            -0.015              -0.006
# 13    CTS  25000         -750            -0.029              -0.037
# 14    CTS  25000         -750            -0.029              -0.037
#
#     priceChangeRatio1M        id  \
# 0                0.138  11003429
# 1               -0.039  10982144
# 2               -0.124  10979596
# 3               -0.265  10971436
# 4               -0.227  10969849
# 5               -0.135  10965715
# 6                0.361  10933075
# 7                0.205  10929446
# 8                0.044  10910740
# 9                0.041  10909232
# 10               0.041  10909234
# 11               0.002  10905392
# 12               0.135  10896695
# 13               0.104  10892796
# 14               0.104  10891835
#
#                                                 title source  \
# 0   CTS:  CBTT Nghị quyết HĐQT về việc phê duyệt v...   HOSE
# 1   CTS:  Thông báo nhận được QĐ chấp thuận thành ...   HOSE
# 2   CTS:  Thông báo Quyết định của UBCKNN về việc ...   HOSE
# 3   CTS:  Giấy chứng nhận đăng ký hoạt động chi nh...   HOSE
# 4   CTS:  Giấy chứng nhận đăng ký hoạt động chi nh...   HOSE
# 5   CTS:  CBTT Nghị quyết HĐQT phê duyệt ký kết hợ...   HOSE
# 6   CTS:  Nghị quyết HĐQT về việc phê duyệt ký kết...   HOSE
# 7   CTS:  Thông báo quyết định của Cục thuế Tp Hà ...   HOSE
# 8   CTS:  Nghị quyết HĐQT về việc phê duyệt ký kết...   HOSE
# 9   CTS:  Thông báo thay đổi giấy chứng nhận ĐKDN ...   HOSE
# 10  CTS:  CBTT Nghị quyết HĐQT phê duyệt ký kết hợ...   HOSE
# 11  CTS:  CBTT Nghị quyết HĐQT tạm hoãn tổ chức ĐH...   HOSE
# 12  CTS:  Báo cáo tỷ lệ an toàn tài chính bán niên...   HOSE
# 13  CTS:  Thông báo nhận được Giấy chứng nhận thàn...   HOSE
# 14  CTS:  CBTT Nghị quyết HĐQT về việc phê duyệt k...   HOSE
#
#             publishDate
# 0   2023-11-24 16:21:00
# 1   2023-11-09 14:19:00
# 2   2023-11-07 17:42:00
# 3   2023-10-30 16:45:00
# 4   2023-10-27 16:51:00
# 5   2023-10-25 09:16:00
# 6   2023-09-20 15:30:00
# 7   2023-09-15 17:20:00
# 8   2023-08-28 15:49:00
# 9   2023-08-25 17:06:00
# 10  2023-08-25 17:05:00
# 11  2023-08-22 15:45:00
# 12  2023-08-15 10:33:00
# 13  2023-08-10 17:20:00
# 14  2023-08-10 09:53:00

# %% [markdown]
# ### 🧧 Lịch sử chi trả cổ tức

# %%
dividend_history("CTS")
# Out:
#    exerciseDate  cashYear  cashDividendPercentage issueMethod
# 0      24/08/22      2022                   0.220       share
# 1      28/03/22      2022                   0.080       share
# 2      13/09/19      2018                   0.100        cash
# 3      07/09/18      2018                   0.090       share
# 4      08/08/17      2017                   0.080       share
# 5      14/07/16      2016                   0.080       share
# 6      28/09/15      2015                   0.060       share
# 7      12/09/14      2013                   0.060        cash
# 8      03/10/13      2012                   0.060        cash
# 9      17/05/12      2011                   0.060        cash
# 10     21/05/10      2009                   0.058        cash

# %% [markdown]
# ### Phân tích tài chính

# %% [markdown]
# #### Chỉ số tài chính (TCBS)

# %%
financial_ratio("CTS", 'quarterly', True)
# Out:
# range                    Q3-2023  Q2-2023  Q1-2023  Q4-2022  Q3-2022  Q2-2022  \
# ticker                       CTS      CTS      CTS      CTS      CTS      CTS
# quarter                       Q3       Q2       Q1       Q4       Q3       Q2
# year                        2023     2023     2023     2022     2022     2022
# priceToEarning              26.5     32.9    102.8     26.5      9.3      6.2
# priceToBook                  2.0      1.6      1.3      1.0      1.3      0.9
# valueBeforeEbitda           18.4     18.7     25.1     18.5     10.4      9.7
# roe                        0.078    0.051    0.013    0.039    0.152    0.163
# roa                        0.022    0.015    0.003    0.012    0.047    0.049
# daysReceivable             671.0    743.0    796.0    762.0    556.0    524.0
# daysInventory                NaN      NaN      NaN      NaN      NaN      NaN
# daysPayable                   10        2        3        3        5       49
# earningPerShare             1019      653      163      477     1776     1889
# bookValuePerShare        13486.0  13031.0  12560.0  12470.0  12505.0  12427.0
# equityOnTotalAsset         0.245    0.276    0.292    0.368    0.328    0.296
# equityOnLiability            0.3      0.4      0.4      0.6      0.5      0.4
# currentPayment               1.3      1.4      1.4      1.6      1.5      1.4
# quickPayment                 1.3      1.4      1.4      1.6      1.5      1.4
# epsChange                   0.56     3.01   -0.659   -0.731    -0.06   -0.305
# ebitdaOnStock             3779.0   3148.0   2217.0   2464.0   4875.0   4929.0
# grossProfitMargin          0.731    0.563    0.565    0.491    0.614    0.227
# operatingProfitMargin      0.602    0.491    0.468    0.303    0.484    0.172
# postTaxMargin              0.265    0.202    0.054      NaN    0.092    0.011
# debtOnEquity                 2.8      2.4      2.4      1.7      1.8      1.9
# debtOnAsset                  0.7      0.7      0.7      0.6      0.6      0.6
# debtOnEbitda                 9.0      9.9     15.6     11.4      6.2      5.8
# assetOnEquity                4.1      3.6      3.4      2.7      3.1      3.4
# capitalBalance              1935     1887     1837     1825     1836     1834
# cashOnEquity               0.171    0.189    0.372    0.068    0.052    0.075
# cashOnCapitalize           0.087    0.107    0.207     0.05    0.042    0.071
# cashCirculation              NaN      NaN      NaN      NaN      NaN      NaN
# revenueOnWorkCapital         0.5      0.5      0.5      0.5      0.7      0.7
# capexOnFixedAsset         -0.315   -0.471   -0.125   -0.117   -0.098   -0.001
# revenueOnAsset               0.1      0.1      0.1      0.1      0.2      0.2
# postTaxOnPreTax              1.0      0.8      0.8      NaN      1.0      0.9
# ebitOnRevenue              0.602    0.491    0.468    0.303    0.484    0.172
# preTaxOnEbit                 0.4      0.5      0.1     -0.1      0.2      0.1
# payableOnEquity              3.1      2.6      2.4      1.7      2.1      2.4
# ebitdaOnStockChange          0.2     0.42     -0.1   -0.495   -0.011   -0.237
# bookValuePerShareChange    0.035    0.037    0.007   -0.003    0.006   -0.002
#
# range                    Q1-2022  Q4-2021  Q3-2021  Q2-2021  ... Q4-2012  \
# ticker                       CTS      CTS      CTS      CTS  ...     CTS
# quarter                       Q1       Q4       Q3       Q2  ...      Q4
# year                        2022     2021     2021     2021  ...    2012
# priceToEarning               9.6     12.8      9.7      8.7  ...     NaN
# priceToBook                  2.1      2.7      1.8      1.6  ...     NaN
# valueBeforeEbitda            8.9      9.7     14.3     11.8  ...     NaN
# roe                        0.243    0.238    0.202    0.196  ...     NaN
# roa                        0.064    0.071     0.07    0.073  ...   0.056
# daysReceivable             530.0    551.0    603.0    657.0  ...     3.0
# daysInventory                NaN      NaN      NaN      NaN  ...     0.0
# daysPayable                    2        1        7      111  ...      13
# earningPerShare             2718     2599     2005     1915  ...     683
# bookValuePerShare        12454.0  12184.0  10907.0  10706.0  ...     NaN
# equityOnTotalAsset         0.239    0.271    0.294    0.309  ...     NaN
# equityOnLiability            0.3      0.4      0.4      0.4  ...     4.4
# currentPayment               1.3      1.4      1.4      1.5  ...     4.2
# quickPayment                 1.3      1.4      1.4      1.5  ...     4.2
# epsChange                  0.046    0.296    0.047    0.095  ...  -0.154
# ebitdaOnStock             6462.0   6043.0   4809.0   4475.0  ...     NaN
# grossProfitMargin           0.63    0.704    0.449    0.844  ...   0.792
# operatingProfitMargin      0.552     0.63    0.375    0.765  ...     NaN
# postTaxMargin              0.254    0.422    0.149    0.498  ...   0.411
# debtOnEquity                 2.4      2.3      2.0      1.8  ...     NaN
# debtOnAsset                  0.6      0.6      0.6      0.6  ...     NaN
# debtOnEbitda                 5.4      4.9      4.8      4.2  ...     NaN
# assetOnEquity                4.2      3.7      3.4      3.2  ...     NaN
# capitalBalance              1846     1814     1608     1575  ...     636
# cashOnEquity               0.143    0.186    0.029     0.09  ...   0.297
# cashOnCapitalize           0.131    0.112    0.012    0.049  ...    0.42
# cashCirculation              NaN      NaN      NaN      NaN  ...    -9.0
# revenueOnWorkCapital         0.7      0.7      0.6      0.6  ...   119.7
# capexOnFixedAsset         -0.014   -0.029   -0.027   -0.026  ...  -0.122
# revenueOnAsset               0.2      0.2      0.2      0.2  ...     0.1
# postTaxOnPreTax              0.8      0.8      0.8      0.8  ...     1.3
# ebitOnRevenue              0.552     0.63    0.375    0.765  ...     NaN
# preTaxOnEbit                 0.5      0.8      0.5      0.8  ...     NaN
# payableOnEquity              3.2      2.7      2.4      2.2  ...     0.2
# ebitdaOnStockChange        0.069    0.257    0.075    0.139  ...     NaN
# bookValuePerShareChange    0.022    0.117    0.019    0.078  ...     NaN
#
# range                   Q3-2012 Q2-2012 Q1-2012 Q4-2011 Q3-2011 Q2-2011  \
# ticker                      CTS     CTS     CTS     CTS     CTS     CTS
# quarter                      Q3      Q2      Q1      Q4      Q3      Q2
# year                       2012    2012    2012    2011    2011    2011
# priceToEarning              NaN     NaN     NaN     NaN     NaN     NaN
# priceToBook                 NaN     NaN     NaN     NaN     NaN     NaN
# valueBeforeEbitda           NaN     NaN     NaN     NaN     NaN     NaN
# roe                         NaN     NaN     NaN     NaN     NaN     NaN
# roa                       0.078    0.08   0.075   0.051   0.071   0.033
# daysReceivable              0.0     1.0     0.0     2.0     0.0     0.0
# daysInventory               3.0     3.0     3.0     2.0     4.0     3.0
# daysPayable                   7       9       7       8       3       3
# earningPerShare             807     786     768     600     692     310
# bookValuePerShare           NaN     NaN     NaN     NaN     NaN     NaN
# equityOnTotalAsset          NaN     NaN     NaN     NaN     NaN     NaN
# equityOnLiability           2.9     3.7     3.4     1.4     4.9     5.3
# currentPayment              3.1     3.6     3.5     2.0     4.9     5.2
# quickPayment                3.1     3.6     3.5     2.0     4.9     5.2
# epsChange                 0.027   0.024   0.279  -0.132    1.23   1.866
# ebitdaOnStock               NaN     NaN     NaN     NaN     NaN     NaN
# grossProfitMargin         0.695   0.661    0.81   0.748    0.62   0.645
# operatingProfitMargin       NaN     NaN     NaN     NaN     NaN     NaN
# postTaxMargin             0.368   0.379    0.49   0.408   0.338   0.379
# debtOnEquity                NaN     NaN     NaN     NaN     NaN     NaN
# debtOnAsset                 NaN     NaN     NaN     NaN     NaN     NaN
# debtOnEbitda                NaN     NaN     NaN     NaN     NaN     NaN
# assetOnEquity               NaN     NaN     NaN     NaN     NaN     NaN
# capitalBalance              622     602     649     628     664     655
# cashOnEquity               0.91   0.395   0.623   1.266   0.473    0.41
# cashOnCapitalize          1.467   0.503   0.699   2.245   0.801   0.641
# cashCirculation            -4.0    -5.0    -4.0    -4.0     1.0     0.0
# revenueOnWorkCapital     4846.0   263.9  3538.3   235.7  2305.8  4222.7
# capexOnFixedAsset        -0.183   -0.16   -0.08  -0.071  -0.214   -0.32
# revenueOnAsset              0.2     0.2     0.2     0.1     0.2     0.2
# postTaxOnPreTax             1.4     1.3     1.3     1.3     1.3     1.3
# ebitOnRevenue               NaN     NaN     NaN     NaN     NaN     NaN
# preTaxOnEbit                NaN     NaN     NaN     NaN     NaN     NaN
# payableOnEquity             0.3     0.3     0.3     0.7     0.2     0.2
# ebitdaOnStockChange         NaN     NaN     NaN     NaN     NaN     NaN
# bookValuePerShareChange     NaN     NaN     NaN     NaN     NaN     NaN
#
# range                   Q1-2011 Q4-2010 Q3-2010
# ticker                      CTS     CTS     CTS
# quarter                      Q1      Q4      Q3
# year                       2011    2010    2010
# priceToEarning              NaN     NaN     NaN
# priceToBook                 NaN     NaN     NaN
# valueBeforeEbitda           NaN     NaN     NaN
# roe                         NaN     NaN     NaN
# roa                       0.011   0.018  -0.007
# daysReceivable              0.0     1.0    46.0
# daysInventory               1.0     1.0     1.0
# daysPayable                   1       2       1
# earningPerShare             108     178     -75
# bookValuePerShare           NaN     NaN     NaN
# equityOnTotalAsset          NaN     NaN     NaN
# equityOnLiability           4.2     3.8     2.8
# currentPayment              4.3     4.1     3.6
# quickPayment                4.3     4.1     3.6
# epsChange                -0.393  -3.356  -1.117
# ebitdaOnStock               NaN     NaN     NaN
# grossProfitMargin         0.427   0.771  -0.591
# operatingProfitMargin       NaN     NaN     NaN
# postTaxMargin             0.181   0.527   -0.83
# debtOnEquity                NaN     NaN     NaN
# debtOnAsset                 NaN     NaN     NaN
# debtOnEbitda                NaN     NaN     NaN
# assetOnEquity               NaN     NaN     NaN
# capitalBalance              637     635     739
# cashOnEquity              0.326   0.285   0.591
# cashOnCapitalize          0.395   0.277   0.666
# cashCirculation             0.0     1.0    46.0
# revenueOnWorkCapital     4934.6   409.6     7.9
# capexOnFixedAsset        -0.301   -0.32  -0.468
# revenueOnAsset              0.2     0.2     0.2
# postTaxOnPreTax             1.3     1.2     1.0
# ebitOnRevenue               NaN     NaN     NaN
# preTaxOnEbit                NaN     NaN     NaN
# payableOnEquity             0.2     0.3     0.4
# ebitdaOnStockChange         NaN     NaN     NaN
# bookValuePerShareChange     NaN     NaN     NaN
#
# [39 rows x 53 columns]

# %%
financial_ratio_compare (symbol_ls=["CTS", "SSI", "VND"], industry_comparison=True, frequency='Yearly', start_year=2010)
# Out:
#                        Chỉ số          2010          2011          2012  \
# 0          Lợi nhuận sau thuế           NaN           NaN           NaN
# 1                         CTS  2.164234e+10  6.389285e+10  7.274012e+10
# 2   Tăng trưởng lợi nhuận (%) -7.905620e-01  1.952215e+00  1.384703e-01
# 3                         SSI  6.885871e+11  7.912901e+10  4.642994e+11
# 4   Tăng trưởng lợi nhuận (%) -1.436335e-01 -8.850850e-01  4.867625e+00
# 5                         VND  1.051528e+11 -2.029581e+11  7.863752e+10
# 6   Tăng trưởng lợi nhuận (%) -5.032907e-01 -2.930126e+00  1.387457e+00
# 7                  Toàn ngành  1.873435e+12 -3.078862e+12  9.951901e+11
# 8   Tăng trưởng lợi nhuận (%) -4.332070e-01 -2.643431e+00  1.323233e+00
# 9                   Doanh thu           NaN           NaN           NaN
# 10                        CTS  1.955928e+11  1.880205e+11  1.756985e+11
# 11  Tăng trưởng doanh thu (%) -3.106119e-01 -3.871432e-02 -6.553550e-02
# 12                        SSI  1.503617e+12  8.480488e+11  8.492942e+11
# 13  Tăng trưởng doanh thu (%)  3.406500e-01 -4.359940e-01  1.468605e-03
# 14                        VND  4.707478e+11  2.766453e+11  2.408770e+11
# 15  Tăng trưởng doanh thu (%)  3.078946e-01 -4.123280e-01 -1.292929e-01
# 16                 Toàn ngành  1.088613e+13  8.194353e+12  5.885821e+12
# 17  Tăng trưởng doanh thu (%)  4.090120e-01 -2.472660e-01 -2.817220e-01
# 18                   Vống hóa           NaN           NaN           NaN
# 19                        CTS  5.766518e+11  5.766518e+11  5.766518e+11
# 20                        SSI  7.338235e+12  7.369585e+12  7.369585e+12
# 21                        VND  1.249988e+12  1.249988e+12  1.249988e+12
# 22                 Toàn ngành  4.149136e+13  3.069325e+13  2.620598e+13
# 23                  EPS (VND)           NaN           NaN           NaN
# 24                        CTS  2.739766e+02  8.088378e+02  9.208379e+02
# 25                        SSI  1.961162e+03  2.244083e+02  1.316744e+03
# 26                        VND  1.051538e+03 -2.029602e+03  7.863831e+02
# 27                 Toàn ngành  7.103748e+02 -1.018717e+03  3.461672e+02
# 28                        P/E           NaN           NaN           NaN
# 29                        CTS  2.664461e+01  9.025295e+00  7.927563e+00
# 30                        SSI  1.065695e+01  9.313380e+01  1.587249e+01
# 31                        VND  1.188735e+01 -6.158844e+00  1.589556e+01
# 32                 Toàn ngành  1.701075e+01 -3.729703e+01  1.940069e+01
# 33                        P/B           NaN           NaN           NaN
# 34                        CTS  7.023319e-01  6.613682e-01  6.475580e-01
# 35                        SSI  1.344169e+00  1.450516e+00  1.419528e+00
# 36                        VND  1.006796e+00  1.203540e+00  1.132901e+00
# 37                 Toàn ngành  1.368862e+00  1.005482e+00  9.332813e-01
# 38             Số CP lưu hành           NaN           NaN           NaN
# 39                        CTS  7.899340e+07  7.899340e+07  7.899340e+07
# 40                        SSI  3.511117e+08  3.526117e+08  3.526117e+08
# 41                        VND  9.999900e+07  9.999900e+07  9.999900e+07
# 42                 Toàn ngành  2.637248e+09  3.022293e+09  2.874883e+09
# 43                 BVPS (VND)           NaN           NaN           NaN
# 44                        CTS  1.039395e+04  1.103772e+04  1.127312e+04
# 45                        SSI  1.554865e+04  1.440867e+04  1.472320e+04
# 46                        VND  1.241563e+04  1.038603e+04  1.103362e+04
# 47                 Toàn ngành  1.243897e+04  1.219012e+04  1.651643e+04
# 48                    ROE (%)           NaN           NaN           NaN
# 49                        CTS  2.586943e-02  7.548062e-02  8.254621e-02
# 50                        SSI  1.339949e-01  1.501503e-02  9.039887e-02
# 51                        VND  1.179531e-01 -1.780223e-01  7.342632e-02
# 52                 Toàn ngành  9.284202e-02 -3.280568e-03  3.907749e-02
# 53                    ROA (%)           NaN           NaN           NaN
# 54                        CTS  2.008952e-02  5.071729e-02  5.642563e-02
# 55                        SSI  8.677912e-02  1.034339e-02  6.409262e-02
# 56                        VND  4.423869e-02 -9.136904e-02  5.036067e-02
# 57                 Toàn ngành  3.421873e-02 -2.395011e-03  2.543337e-02
#
#             2013          2014          2015          2016          2017  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1   6.523698e+10  6.644957e+10  7.687122e+10  8.318065e+10  1.098545e+11
# 2  -1.031500e-01  1.858754e-02  1.568354e-01  8.207799e-02  3.206735e-01
# 3   4.180448e+11  7.448302e+11  8.381536e+11  9.467034e+11  1.161853e+12
# 4  -9.962231e-02  7.816995e-01  1.252949e-01  1.295106e-01  2.272619e-01
# 5   1.244270e+11  1.573475e+11  1.817771e+11  1.862875e+11  4.810089e+11
# 6   5.822857e-01  2.645768e-01  1.552585e-01  2.481313e-02  1.582078e+00
# 7   1.624025e+12  2.524560e+12  2.037750e+12  1.948862e+12  4.749292e+12
# 8   6.318730e-01  5.545080e-01 -1.928290e-01 -4.362000e-02  1.436956e+00
# 9            NaN           NaN           NaN           NaN           NaN
# 10  1.484763e+11  1.772665e+11  2.328362e+11  2.337112e+11  2.868300e+11
# 11 -1.549370e-01  1.939039e-01  3.134815e-01  3.757970e-03  2.272839e-01
# 12  7.269438e+11  1.564610e+12  1.547519e+12  2.445730e+12  2.898078e+12
# 13 -1.440613e-01  1.152312e+00 -1.092376e-02  5.804203e-01  1.849541e-01
# 14  2.626190e+11  4.352901e+11  5.341234e+11  7.313922e+11  1.220326e+12
# 15  9.026175e-02  6.574967e-01  2.270515e-01  3.693320e-01  6.684975e-01
# 16  4.458839e+12  7.283285e+12  6.947518e+12  8.675135e+12  1.331469e+13
# 17 -2.424440e-01  6.334480e-01 -4.610000e-02  2.486660e-01  5.348100e-01
# 18           NaN           NaN           NaN           NaN           NaN
# 19  5.766518e+11  5.766518e+11  6.112315e+11  7.324324e+11  1.279253e+12
# 20  7.394314e+12  7.394314e+12  1.003333e+13  1.014432e+13  1.910243e+13
# 21  1.249988e+12  1.937477e+12  1.937477e+12  1.983977e+12  4.882442e+12
# 22  3.312589e+13  2.788154e+13  2.781173e+13  3.331316e+13  7.206137e+13
# 23           NaN           NaN           NaN           NaN           NaN
# 24  8.258535e+02  8.412041e+02  8.245344e+02  9.198982e+02  1.124948e+03
# 25  1.181602e+03  2.105260e+03  1.685840e+03  1.789637e+03  2.323410e+03
# 26  1.244283e+03  1.015157e+03  1.119994e+03  1.198246e+03  2.828743e+03
# 27  5.041282e+02  6.950475e+02  7.408004e+02  6.493610e+02  1.437873e+03
# 28           NaN           NaN           NaN           NaN           NaN
# 29  8.839340e+00  8.678037e+00  8.853481e+00  8.805322e+00  1.164498e+01
# 30  1.768785e+01  9.927517e+00  1.239738e+01  1.156659e+01  1.644135e+01
# 31  1.004595e+01  1.231336e+01  1.116077e+01  1.068228e+01  1.113569e+01
# 32  1.489491e+01  6.828669e+00  8.392592e+00  2.650895e+01  1.706227e+01
# 33           NaN           NaN           NaN           NaN           NaN
# 34  6.408297e-01  6.227370e-01  6.142573e-01  6.846810e-01  1.092563e+00
# 35  1.410541e+00  1.299311e+00  1.509573e+00  1.434137e+00  2.237370e+00
# 36  1.044290e+00  1.055679e+00  1.001057e+00  1.018624e+00  1.946628e+00
# 37  1.603939e+00  1.198488e+00  1.132848e+00  1.436330e+00  2.528059e+00
# 38           NaN           NaN           NaN           NaN           NaN
# 39  7.899340e+07  7.899340e+07  8.373034e+07  9.042376e+07  9.765294e+07
# 40  3.537949e+08  3.537949e+08  4.800637e+08  4.900637e+08  5.000637e+08
# 41  9.999900e+07  1.549982e+08  1.549982e+08  1.549982e+08  1.549982e+08
# 42  3.221451e+09  3.632212e+09  2.750741e+09  3.001200e+09  3.302997e+09
# 43           NaN           NaN           NaN           NaN           NaN
# 44  1.139148e+04  1.172244e+04  1.188427e+04  1.183033e+04  1.199015e+04
# 45  1.481701e+04  1.608545e+04  1.384497e+04  1.443377e+04  1.707362e+04
# 46  1.196986e+04  1.184072e+04  1.248680e+04  1.256597e+04  1.618183e+04
# 47  1.289622e+04  1.294545e+04  1.152429e+04  1.083055e+04  1.265195e+04
# 48           NaN           NaN           NaN           NaN           NaN
# 49  7.287606e-02  7.278764e-02  8.002960e-02  8.056953e-02  9.805740e-02
# 50  8.013314e-02  1.362519e-01  1.358718e-01  1.308127e-01  1.419871e-01
# 51  1.081821e-01  1.037822e-01  9.641502e-02  9.593314e-02  2.155069e-01
# 52  6.600924e-02  1.275588e-01  1.277040e-01  8.746922e-02  1.743563e-01
# 53           NaN           NaN           NaN           NaN           NaN
# 54  5.996917e-02  5.982267e-02  7.031585e-02  6.741211e-02  6.741811e-02
# 55  5.330182e-02  8.963324e-02  7.956701e-02  7.237721e-02  7.090694e-02
# 56  6.952517e-02  6.440637e-02  4.179094e-02  3.408196e-02  7.264467e-02
# 57  4.661992e-02  8.790526e-02  5.824827e-02  4.929604e-02  8.659921e-02
#
#             2018          2019          2020          2021          2022
# 0            NaN           NaN           NaN           NaN           NaN
# 1   1.506500e+11  1.148052e+11  1.281874e+11  3.865038e+11  7.106794e+10
# 2   3.713593e-01 -2.379345e-01  1.165648e-01  2.015147e+00 -8.161262e-01
# 3   1.304930e+12  9.092014e+11  1.257372e+12  2.695914e+12  1.699320e+12
# 4   1.231457e-01 -3.032567e-01  3.829416e-01  1.144085e+00 -3.696683e-01
# 5   3.731363e+11  3.826585e+11  6.927669e+11  2.382924e+12  1.220280e+12
# 6  -2.242632e-01  2.551948e-02  8.104048e-01  2.439719e+00 -4.879065e-01
# 7   5.472926e+12  3.999449e+12  6.238241e+12  1.670639e+13  5.392880e+12
# 8   1.523660e-01 -2.692300e-01  5.597740e-01  1.678061e+00 -6.771960e-01
# 9            NaN           NaN           NaN           NaN           NaN
# 10  6.527860e+11  5.049779e+11  6.089867e+11  1.064553e+12  8.721551e+11
# 11  1.275864e+00 -2.264265e-01  2.059669e-01  7.480733e-01 -1.807314e-01
# 12  3.672838e+12  3.234978e+12  4.366801e+12  7.443182e+12  6.335823e+12
# 13  2.673359e-01 -1.192157e-01  3.498704e-01  7.044930e-01 -1.487749e-01
# 14  1.538489e+12  1.501878e+12  2.134529e+12  6.039233e+12  6.829224e+12
# 15  2.607194e-01 -2.379661e-02  4.212398e-01  1.829305e+00  1.308098e-01
# 16  1.771066e+13  1.530972e+13  2.118598e+13  4.379040e+13  3.941306e+13
# 17  3.301590e-01 -1.355640e-01  3.838250e-01  1.066951e+00 -9.996100e-02
# 18           NaN           NaN           NaN           NaN           NaN
# 19  9.834740e+11  7.237687e+11  1.591227e+12  4.342612e+12  1.933598e+12
# 20  1.451131e+13  8.416051e+12  2.022883e+13  4.588935e+13  2.833147e+13
# 21  3.945700e+12  3.019893e+12  6.227152e+12  3.309929e+13  1.735428e+13
# 22  5.594997e+13  3.465592e+13  9.257256e+13  2.493081e+14  1.433677e+14
# 23           NaN           NaN           NaN           NaN           NaN
# 24  1.413409e+03  1.078625e+03  1.204355e+03  3.631306e+03  4.778052e+02
# 25  2.558367e+03  1.782525e+03  2.085383e+03  2.737663e+03  1.139619e+03
# 26  1.702463e+03  1.734270e+03  3.162393e+03  5.478682e+03  1.002000e+03
# 27  1.308200e+03  8.847629e+02  1.248771e+03  1.993604e+03  5.277546e+02
# 28           NaN           NaN           NaN           NaN           NaN
# 29  6.537387e+00  6.304322e+00  1.241329e+01  1.123563e+01  2.720774e+01
# 30  1.112037e+01  9.256531e+00  1.608817e+01  1.702182e+01  1.667224e+01
# 31  1.051418e+01  7.899576e+00  8.933109e+00  1.389020e+01  1.422156e+01
# 32  9.748022e+00  7.745710e+00  1.348312e+01  1.353225e+01  2.069633e+01
# 33           NaN           NaN           NaN           NaN           NaN
# 34  7.479646e-01  5.512150e-01  1.106987e+00  2.396838e+00  1.042753e+00
# 35  1.596631e+00  9.014424e-01  2.062192e+00  3.241342e+00  1.273609e+00
# 36  1.321813e+00  9.297305e-01  1.628408e+00  3.369748e+00  1.195637e+00
# 37  1.126681e+00  6.150615e-01  1.449369e+00  2.440162e+00  1.096084e+00
# 38           NaN           NaN           NaN           NaN           NaN
# 39  1.064366e+08  1.064366e+08  1.064366e+08  1.064366e+08  1.487383e+08
# 40  5.100637e+08  5.100637e+08  6.029456e+08  9.847500e+08  1.491130e+09
# 41  2.204302e+08  2.204302e+08  2.204302e+08  4.349447e+08  1.217844e+09
# 42  4.183554e+09  4.520363e+09  4.995503e+09  8.379996e+09  1.021854e+10
# 43           NaN           NaN           NaN           NaN           NaN
# 44  1.235353e+04  1.233638e+04  1.350513e+04  1.702243e+04  1.246700e+04
# 45  1.781876e+04  1.830400e+04  1.626910e+04  1.437676e+04  1.491824e+04
# 46  1.354201e+04  1.473545e+04  1.734823e+04  2.258329e+04  1.191833e+04
# 47  1.216365e+04  1.270078e+04  1.325547e+04  1.295771e+04  1.387158e+04
# 48           NaN           NaN           NaN           NaN           NaN
# 49  1.212010e-01  8.736672e-02  9.321085e-02  2.379035e-01  3.877002e-02
# 50  1.480637e-01  9.869264e-02  1.313485e-01  2.249698e-01  9.336267e-02
# 51  1.357194e-01  1.228154e-01  1.960359e-01  3.493580e-01  1.002812e-01
# 52  1.528675e-01  8.605934e-02  1.253453e-01  2.380158e-01  7.453500e-02
# 53           NaN           NaN           NaN           NaN           NaN
# 54  6.824472e-02  4.270554e-02  3.624410e-02  7.053379e-02  1.212489e-02
# 55  6.127871e-02  3.574626e-02  4.003501e-02  6.228820e-02  3.299028e-02
# 56  4.011499e-02  3.461145e-02  5.217970e-02  9.152619e-02  3.212726e-02
# 57  7.520785e-02  3.960251e-02  5.703597e-02  9.889188e-02  2.822634e-02

# %% [markdown]
# #### Báo cáo tài chính
#
# * Income Statement: Báo cáo doanh thu
#
# * Balance Sheet: Bảng cân đối kế toán
#
# * Cashflow: Báo cáo lưu chuyển tiền tệ

# %% [markdown]
# ##### Nguồn SSI

# %% [markdown]
# Dữ liệu trả về có đơn vị mặc định Tỷ VND

# %%
financial_report (symbol='CTS', report_type='IncomeStatement', frequency='Quarterly')
# Out:
#                                              CHỈ TIÊU       Q2 2021  \
# 0                                 Doanh thu hoạt động  2.548297e+11
# 1   Lãi từ các tài sản tài chính ghi nhận thông qu...  1.431925e+11
# 2                       Lãi bán các tài sản tài chính  2.760954e+10
# 3   Chêch lệch tăng đánh giá lại các tài sản tài c...  8.890308e+10
# 4   Cổ tức, tiền lãi phát sinh từ tài sản tài chín...  2.667987e+10
# ..                                                ...           ...
# 78          Thu nhập toàn diện phân bổ cho chủ sở hữu  1.268058e+11
# 79  Thu nhập toàn diện phân bổ cho cổ đông không k...  0.000000e+00
# 80             Thu nhập thuần trên cổ phiếu phổ thông  0.000000e+00
# 81                          Lãi cơ bản trên cổ phiếu   1.192000e+03
# 82                   Thu nhập pha loãng trên cổ phiếu  0.000000e+00
#
#          Q3 2021       Q4 2021       Q1 2022       Q2 2022       Q3 2022  \
# 0   2.013442e+11  4.501579e+11  2.264412e+11  3.098045e+11  1.439564e+11
# 1   9.740064e+10  3.173530e+11  9.795139e+10  2.029242e+11  4.727474e+10
# 2   4.622704e+09  1.484420e+11  6.288634e+10  1.590521e+10  6.279546e+09
# 3   8.092503e+10  1.525241e+11  5.985517e+09  1.603170e+11  1.366435e+10
# 4   1.185291e+10  1.638683e+10  2.907953e+10  2.670194e+10  2.733085e+10
# ..           ...           ...           ...           ...           ...
# 78  3.001149e+10  1.897897e+11  5.760451e+10 -3.989289e+09  1.161657e+10
# 79  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 80  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 81  2.820000e+02  1.784000e+03  5.410000e+02 -9.000000e+00  1.150000e+02
# 82  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#          Q4 2022       Q1 2023       Q2 2023       Q3 2023
# 0   1.919530e+11  1.990163e+11  3.787698e+11  2.557544e+11
# 1   9.548191e+10  8.764977e+10  2.257481e+11  8.436731e+10
# 2   3.068641e+09  4.145925e+10  1.520655e+11  1.452073e+10
# 3   5.693829e+10  3.860060e+10  6.323989e+10  5.649124e+10
# 4   3.547498e+10  7.589912e+09  1.044273e+10  1.335534e+10
# ..           ...           ...           ...           ...
# 78 -5.311273e+09  1.497126e+10  8.342798e+10  6.768349e+10
# 79  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 80  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 81 -2.200000e+01  7.200000e+01  5.150000e+02  4.550000e+02
# 82  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# [83 rows x 11 columns]

# %%
financial_report (symbol='CTS', report_type='BalanceSheet', frequency='Quarterly')
# Out:
#                                       CHỈ TIÊU       Q2 2021       Q3 2021  \
# 0                            TỔNG CỘNG TÀI SẢN  5.145502e+12  5.517816e+12
# 1                             TÀI SẢN NGẮN HẠN  5.065915e+12  5.440394e+12
# 2                   Tài sản tài chính ngắn hạn  4.704200e+12  5.010904e+12
# 3                    Tiền và tương đương tiền   1.432634e+11  4.720617e+10
# 4                                         Tiền  1.432634e+11  4.720617e+10
# ..                                         ...           ...           ...
# 155                   Vốn ngân sách nhà nước    0.000000e+00  0.000000e+00
# 156          Nguồn kinh phí đã hình thành TSCĐ  0.000000e+00  0.000000e+00
# 157  LỢI ÍCH CỦA CỔ ĐÔNG THIỂU SỐ (trước 2015)  0.000000e+00  0.000000e+00
# 158                        TỔNG CỘNG NGUỒN VỐN  5.145502e+12  5.517816e+12
# 159      LỢI NHUẬN ĐÃ PHÂN PHỐI CHO NHÀ ĐẦU TƯ  0.000000e+00  0.000000e+00
#
#           Q4 2021       Q1 2022       Q2 2022       Q3 2022       Q4 2022  \
# 0    6.685686e+12  7.736635e+12  6.236224e+12  5.673231e+12  5.036970e+12
# 1    6.610379e+12  7.663157e+12  6.164772e+12  5.595968e+12  4.961836e+12
# 2    6.025552e+12  6.340984e+12  5.369165e+12  5.138226e+12  4.950488e+12
# 3    3.365850e+11  2.657481e+11  1.386745e+11  9.583052e+10  1.263470e+11
# 4    3.365850e+11  2.657481e+11  1.386745e+11  9.583052e+10  1.263470e+11
# ..            ...           ...           ...           ...           ...
# 155  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 156  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 157  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 158  6.685686e+12  7.736635e+12  6.236224e+12  5.673231e+12  5.036970e+12
# 159  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#           Q1 2023       Q2 2023       Q3 2023
# 0    6.406208e+12  7.021398e+12  8.194782e+12
# 1    6.333871e+12  6.943960e+12  8.104398e+12
# 2    6.325921e+12  6.686428e+12  7.594308e+12
# 3    6.950490e+11  3.662940e+11  3.437648e+11
# 4    6.950490e+11  3.662940e+11  3.437648e+11
# ..            ...           ...           ...
# 155  0.000000e+00  0.000000e+00  0.000000e+00
# 156  0.000000e+00  0.000000e+00  0.000000e+00
# 157  0.000000e+00  0.000000e+00  0.000000e+00
# 158  6.406208e+12  7.021398e+12  8.194782e+12
# 159  0.000000e+00  0.000000e+00  0.000000e+00
#
# [160 rows x 11 columns]

# %%
financial_report (symbol='CTS', report_type='CashFlow', frequency='Quarterly')
# Out:
#                                              CHỈ TIÊU       Q2 2021  \
# 0   Lưu chuyển thuần từ hoạt động kinh doanh chứng...  2.449262e+11
# 1   Lợi nhuận từ hoạt động kinh doanh trước thay đ...  8.025353e+10
# 2                                Lợi nhuận trước thuế  1.585317e+11
# 3                            Điều chỉnh cho các khoản -1.418760e+10
# 4                            Khấu hao tài sản cố định  2.436895e+09
# ..                                                ...           ...
# 93          Tiền và các khoản tương đương tiền đầu kỳ  6.369694e+10
# 94                Tiền mặt, tiền gửi ngân hàng đầu kỳ  6.369694e+10
# 95                         Các khoản tương đương tiền  0.000000e+00
# 96  Ảnh hưởng của thay đổi tỷ giá hối đoán quy đổi...  0.000000e+00
# 97        Tiền và các khoảng tương đương tiền cuối kỳ  1.432634e+11
#
#          Q3 2021       Q4 2021       Q1 2022       Q2 2022       Q3 2022  \
# 0  -5.355204e+11 -5.018765e+11 -3.499498e+11  7.752107e+11  1.911542e+11
# 1  -3.777142e+10  2.548259e+11  8.700873e+10  3.653995e+10  8.930853e+09
# 2   3.665286e+10  2.372519e+11  6.857547e+10  3.900688e+09  1.347039e+10
# 3   6.500752e+09  1.439315e+10 -3.149248e+10 -1.589058e+10 -2.528020e+10
# 4   2.144722e+09  2.089398e+09  1.978763e+09  1.927028e+09  2.057271e+09
# ..           ...           ...           ...           ...           ...
# 93  1.432634e+11  4.720617e+10  3.365850e+11  2.657481e+11  1.386745e+11
# 94  1.432634e+11  4.720617e+10  3.365850e+11  2.657481e+11  1.386745e+11
# 95  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 96  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 97  8.526550e+10  3.365850e+11  2.657481e+11  1.386745e+11  9.583052e+10
#
#          Q4 2022       Q1 2023       Q2 2023       Q3 2023
# 0   2.293434e+11 -8.332713e+11 -5.564554e+11 -9.251566e+11
# 1  -4.973245e+09  3.069722e+10  1.416858e+11  9.673803e+09
# 2  -7.152379e+09  1.348757e+10  9.452949e+10  6.474025e+10
# 3  -9.758044e+09 -1.103872e+10 -2.841097e+10 -1.874096e+10
# 4   2.338789e+09  2.376210e+09  1.267457e+09  1.058315e+09
# ..           ...           ...           ...           ...
# 93  9.583052e+10  1.583470e+11  6.950490e+11  3.712301e+11
# 94  9.583052e+10  1.263470e+11  6.950490e+11  3.662940e+11
# 95  0.000000e+00  3.200000e+10  0.000000e+00  0.000000e+00
# 96  0.000000e+00  0.000000e+00  0.000000e+00  4.936056e+09
# 97  1.263470e+11  6.950490e+11  3.712301e+11  3.437648e+11
#
# [98 rows x 11 columns]

# %% [markdown]
# ##### Nguồn TCBS

# %%
# Bổ sung param `get_all` để lấy tất cả báo cáo hoặc 5 năm gần nhất hoặc 10 quý gần nhất
financial_flow(symbol="CTS", report_type='incomestatement', report_range='quarterly', get_all=False)
# Out:
#         ticker  revenue  yearRevenueGrowth  quarterRevenueGrowth  \
# index
# 2023-Q3    CTS      256              0.777                -0.325
# 2023-Q2    CTS      379              0.223                 0.903
# 2023-Q1    CTS      199             -0.121                 0.037
# 2022-Q4    CTS      192             -0.574                 0.333
# 2022-Q3    CTS      144             -0.285                -0.535
# 2022-Q2    CTS      310              0.216                 0.368
# 2022-Q1    CTS      226              0.431                -0.497
# 2021-Q4    CTS      450              0.743                 1.236
# 2021-Q3    CTS      201              0.737                -0.210
# 2021-Q2    CTS      255              0.389                 0.611
#
#          costOfGoodSold  grossProfit  operationExpense  operationProfit  \
# index
# 2023-Q3             -69          187               -33              154
# 2023-Q2            -166          213               -27              186
# 2023-Q1             -87          112               -19               93
# 2022-Q4             -98           94               -36               58
# 2022-Q3             -56           88               -19               70
# 2022-Q2            -239           70               -17               53
# 2022-Q1             -84          143               -18              125
# 2021-Q4            -133          317               -33              284
# 2021-Q3            -111           90               -15               76
# 2021-Q2             -40          215               -20              195
#
#          yearOperationProfitGrowth  quarterOperationProfitGrowth  ...  \
# index                                                             ...
# 2023-Q3                      1.209                        -0.173  ...
# 2023-Q2                      2.495                         0.998  ...
# 2023-Q1                     -0.255                         0.602  ...
# 2022-Q4                     -0.795                        -0.165  ...
# 2022-Q3                     -0.078                         0.309  ...
# 2022-Q2                     -0.727                        -0.574  ...
# 2022-Q1                      0.567                        -0.559  ...
# 2021-Q4                      0.871                         2.756  ...
# 2021-Q3                      0.919                        -0.612  ...
# 2021-Q2                      0.431                         1.442  ...
#
#          postTaxProfit  shareHolderIncome  yearShareHolderIncomeGrowth  \
# index
# 2023-Q3             68                 68                        4.103
# 2023-Q2             76                 76                       20.830
# 2023-Q1             11                 11                       -0.813
# 2022-Q4             -3                 -3                          NaN
# 2022-Q3             13                 13                       -0.558
# 2022-Q2              4                  4                       -0.972
# 2022-Q1             58                 58                        0.444
# 2021-Q4            190                190                        0.869
# 2021-Q3             30                 30                        0.809
# 2021-Q2            127                127                        0.243
#
#          quarterShareHolderIncomeGrowth  investProfit  serviceProfit  \
# index
# 2023-Q3                          -0.115          None           None
# 2023-Q2                           6.096          None           None
# 2023-Q1                             NaN          None           None
# 2022-Q4                             NaN          None           None
# 2022-Q3                           2.786          None           None
# 2022-Q2                          -0.939          None           None
# 2022-Q1                          -0.696          None           None
# 2021-Q4                           5.324          None           None
# 2021-Q3                          -0.763          None           None
# 2021-Q2                           2.178          None           None
#
#         otherProfit provisionExpense operationIncome ebitda
# index
# 2023-Q3        None             None            None    155
# 2023-Q2        None             None            None    187
# 2023-Q1        None             None            None     96
# 2022-Q4        None             None            None     60
# 2022-Q3        None             None            None     72
# 2022-Q2        None             None            None     55
# 2022-Q1        None             None            None    127
# 2021-Q4        None             None            None    286
# 2021-Q3        None             None            None     78
# 2021-Q2        None             None            None    197
#
# [10 rows x 22 columns]

# %%
financial_flow(symbol="CTS", report_type='balancesheet', report_range='quarterly', get_all=False)
# Out:
#         ticker  shortAsset  cash  shortInvest  shortReceivable  inventory  \
# index
# 2023-Q3    CTS        8104   344         7043              207          0
# 2023-Q2    CTS        6944   366         6136              184          0
# 2023-Q1    CTS        6334   695         5424              207          0
# 2022-Q4    CTS        4962   126         4756               68          0
# 2022-Q3    CTS        5596    96         4941              101          0
# 2022-Q2    CTS        6165   139         5140               90          0
# 2022-Q1    CTS        7663   266         5894              181          0
# 2021-Q4    CTS        6610   337         5608               81          0
# 2021-Q3    CTS        5440    47         4875               89          0
# 2021-Q2    CTS        5066   143         4470               91          0
#
#          longAsset  fixedAsset  asset  debt  ...  oweCentralBank  \
# index                                        ...
# 2023-Q3         90          46   8195  6189  ...            None
# 2023-Q2         77          39   7021  5084  ...            None
# 2023-Q1         72          39   6406  4538  ...            None
# 2022-Q4         75          42   5037  3183  ...            None
# 2022-Q3         77          43   5673  3814  ...            None
# 2022-Q2         71          41   6236  4388  ...            None
# 2022-Q1         73          43   7737  5885  ...            None
# 2021-Q4         75          45   6686  4874  ...            None
# 2021-Q3         77          47   5518  3896  ...            None
# 2021-Q2         80          49   5146  3553  ...            None
#
#          valuablePaper  payableInterest  receivableInterest deposit otherDebt  \
# index
# 2023-Q3           None             None                None    None         2
# 2023-Q2           None             None                None    None         2
# 2023-Q1           None             None                None    None         1
# 2022-Q4           None             None                None    None         1
# 2022-Q3           None             None                None    None         1
# 2022-Q2           None             None                None    None         1
# 2022-Q1           None             None                None    None         2
# 2021-Q4           None             None                None    None         1
# 2021-Q3           None             None                None    None         1
# 2021-Q2           None             None                None    None         1
#
#          fund unDistributedIncome minorShareHolderProfit payable
# index
# 2023-Q3  None                   0                      0    6189
# 2023-Q2  None                   0                      0    5084
# 2023-Q1  None                   0                      0    4538
# 2022-Q4  None                   0                      0    3183
# 2022-Q3  None                   0                      0    3814
# 2022-Q2  None                   0                      0    4388
# 2022-Q1  None                   0                      0    5885
# 2021-Q4  None                   0                      0    4874
# 2021-Q3  None                   0                      0    3896
# 2021-Q2  None                   0                      0    3553
#
# [10 rows x 35 columns]

# %%
financial_flow(symbol="CTS", report_type='cashflow', report_range='quarterly', get_all=False)
# Out:
#         ticker  investCost  fromInvest  fromFinancial  fromSale  freeCashFlow
# index
# 2023-Q3    CTS           0           0            897      -925           162
# 2023-Q2    CTS         -14         -14            246      -556            34
# 2023-Q1    CTS           0           0           1370      -833            84
# 2022-Q4    CTS          -1          -1           -198       229           108
# 2022-Q3    CTS          -4          -4           -230       191           273
# 2022-Q2    CTS           0          -2           -901       775           274
# 2022-Q1    CTS           0           1            278      -350           434
# 2021-Q4    CTS           0           0            791      -502           424
# 2021-Q3    CTS           0           0            477      -536           251
# 2021-Q2    CTS          -1           0           -165       245           365

# %% [markdown]
# #### Định giá (Mới)

# %%
stock_evaluation (symbol='CTS', period=1, time_window='D')
# Out:
#     ticker   fromDate     toDate    PE   PB  industryPE  vnindexPE  \
# 0      CTS 2022-11-28 2022-11-28  20.1  0.8         9.6       10.6
# 1      CTS 2022-11-29 2022-11-29  21.6  0.8         9.9       10.9
# 2      CTS 2022-11-30 2022-11-30  23.0  0.9        10.1       11.0
# 3      CTS 2022-12-01 2022-12-01  23.5  0.9         9.9       10.9
# 4      CTS 2022-12-02 2022-12-02  25.1  1.0        10.5       11.3
# ..     ...        ...        ...   ...  ...         ...        ...
# 245    CTS 2023-11-21 2023-11-21  27.0  2.0        26.8       14.4
# 246    CTS 2023-11-22 2023-11-22  27.8  2.1        27.3       14.4
# 247    CTS 2023-11-23 2023-11-23  25.9  2.0        25.7       14.2
# 248    CTS 2023-11-24 2023-11-24  26.8  2.0        26.4       14.2
# 249    CTS 2023-11-27 2023-11-27  26.0  2.0        25.9       14.1
#
#      industryPB  vnindexPB
# 0           0.9        1.5
# 1           0.9        1.6
# 2           0.9        1.6
# 3           0.9        1.6
# 4           1.0        1.6
# ..          ...        ...
# 245         1.5        1.6
# 246         1.5        1.6
# 247         1.4        1.5
# 248         1.5        1.5
# 249         1.4        1.5
#
# [250 rows x 9 columns]

# %% [markdown]
# ## 2.3. Technical Analysis | Phân tích kỹ thuật

# %% [markdown]
# ### 📈 Historical Price | Giá lịch sử

# %%
stock_historical_data(symbol="CTS", start_date="2021-01-01", end_date="2023-11-28", resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')
# Out:
#            time   open   high    low  close   volume ticker
# 0    2021-01-04  12020  12090  11810  12090   518500    CTS
# 1    2021-01-05  12520  12910  12310  12840  1915600    CTS
# 2    2021-01-06  13310  13590  12520  12730  1452500    CTS
# 3    2021-01-07  12990  13060  12730  12770  1310700    CTS
# 4    2021-01-08  13200  13200  12450  12520  1454800    CTS
# ..          ...    ...    ...    ...    ...      ...    ...
# 721  2023-11-22  27550  28400  27300  28350  2226200    CTS
# 722  2023-11-23  28500  28650  26400  26400  2255800    CTS
# 723  2023-11-24  26600  27500  25500  27300  2725000    CTS
# 724  2023-11-27  27300  27400  26500  26500  1138400    CTS
# 725  2023-11-28  26400  27000  25650  27000  1562100    CTS
#
# [726 rows x 7 columns]

# %%
stock_historical_data("VNINDEX", "2023-06-01", "2023-09-18", "1D", "index")
# Out:
#           time     open     high      low    close      volume   ticker
# 0   2023-06-01  1076.50  1078.39  1071.61  1078.39   852591680  VNINDEX
# 1   2023-06-02  1084.19  1092.24  1083.36  1090.84  1025982016  VNINDEX
# 2   2023-06-05  1099.66  1103.81  1096.76  1097.82   942253440  VNINDEX
# 3   2023-06-06  1098.80  1108.31  1098.28  1108.31   837786240  VNINDEX
# 4   2023-06-07  1110.79  1112.28  1104.26  1109.54   995078784  VNINDEX
# ..         ...      ...      ...      ...      ...         ...      ...
# 71  2023-09-12  1223.55  1245.44  1220.85  1245.44   963572096  VNINDEX
# 72  2023-09-13  1249.06  1250.61  1232.84  1238.39  1259350912  VNINDEX
# 73  2023-09-14  1238.21  1244.21  1223.03  1223.81  1218798208  VNINDEX
# 74  2023-09-15  1225.90  1233.87  1220.27  1227.36   909883648  VNINDEX
# 75  2023-09-18  1227.36  1227.36  1203.88  1211.81   841376320  VNINDEX
#
# [76 rows x 7 columns]

# %%
stock_historical_data (symbol='VN30F1M', start_date='2023-09-01', end_date='2023-09-18', resolution='1D', type='derivative')
# Out:
#          time    open    high     low   close  volume   ticker
# 0  2023-09-05  1237.7  1246.3  1236.5  1242.5  139348  VN30F1M
# 1  2023-09-06  1240.8  1263.0  1237.7  1263.0  198718  VN30F1M
# 2  2023-09-07  1262.1  1265.5  1248.6  1255.2  216918  VN30F1M
# 3  2023-09-08  1255.1  1259.2  1248.3  1249.9  189971  VN30F1M
# 4  2023-09-11  1259.1  1261.8  1217.0  1233.0  230383  VN30F1M
# 5  2023-09-12  1230.2  1257.0  1228.4  1257.0  226097  VN30F1M
# 6  2023-09-13  1257.0  1260.6  1236.1  1245.0  272411  VN30F1M
# 7  2023-09-14  1246.3  1251.8  1227.1  1235.0  286810  VN30F1M
# 8  2023-09-15  1238.3  1244.9  1233.8  1240.5  259850  VN30F1M
# 9  2023-09-18  1236.0  1236.0  1213.0  1222.0  256215  VN30F1M

# %% [markdown]
# ## 2.4. 👓 Stock screening | Lọc cổ phiếu

# %% [markdown]
# ### Comparison | So sánh cổ phiếu

# %% [markdown]
# #### 📊 Price Table | Bảng giá

# %%
price_depth('CTS,SSI,VND')
# Out:
#   Mã CP  Giá tham chiếu  Giá Trần  Giá Sàn  Giá mua 3 KL mua 3  Giá mua 2  \
# 0   CTS           26500     28350    24650      26950       40      26900
# 1   SSI           31000     33150    28850      31350      920      31300
# 2   VND           20600     22000    19200      20750     7480      20700
#
#   KL mua 2  Giá mua 1 KL mua 1  ...  Giá bán 1  KL bán 1  Giá bán 2 KL bán 2  \
# 0      400      26850       30  ...      27000      1690      27050     2610
# 1     1730      31250     2350  ...      31400     10740      31450    17280
# 2    45530      20650     7680  ...      20800     16560      20850    18000
#
#    Giá bán 3 KL bán 3  Tổng Khối Lượng ĐTNN Mua  ĐTNN Bán  ĐTNN Room
# 0      27100      700           156210     3390      6400   70720082
# 1      31500    74960          2139680   128700    136965  832051883
# 2      20900    31050          2642490    55370    154290  929887692
#
# [3 rows x 22 columns]

# %%
price_board('CTS,SSI,VND')
# Out:
#   Mã CP      Giá  KLBD/TB5D  T.độ GD  KLGD ròng(CM)  %KLGD ròng (CM)  \
# 0   CTS  27000.0       0.77     1.63              0              0.0
# 1   SSI  31400.0       1.00     1.15         616400             34.7
# 2   VND  20800.0       0.82     1.33         736100             28.5
#
#          RSI  MACD Hist MACD Signal Tín hiệu KT  ... Khớp nhiều nhất  \
# 0  55.773543       0.24     Neutral     Neutral  ...           26000
# 1  51.118254       0.08     Neutral     Neutral  ...           30500
# 2  52.860037       0.13     Neutral     Neutral  ...           20600
#
#    Đ.góp VNINDEX  %Giá - %VNI (1M)  %Giá - %VNI (1Y)  VNINDEX P/E  \
# 0           0.02              19.0             182.4      14.0738
# 1           0.15               4.9              76.4      14.0738
# 2           0.06               9.5              71.1      14.0738
#
#    VNINDEX P/B  vnid3d  vnid1m  vnid3m  vnid1y
# 0       1.5348     0.0     3.1    -8.1    12.0
# 1       1.5348     0.0     3.1    -8.1    12.0
# 2       1.5348     0.0     3.1    -8.1    12.0
#
# [3 rows x 49 columns]

# %% [markdown]
# #### 🏭 Industry Analysis | Phân tích ngành

# %%
industry_analysis("VNM", lang="en")
# Out:
# Empty DataFrame
# Columns: [VNM]
# Index: []

# %% [markdown]
# #### 🔬 Stocks List Analysis | Phân tích danh sách mã cổ phiếu

# %%
stock_ls_analysis('CTS')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 stock_ls_analysis('CTS')
#
# File D:\PyProjects\Anaconda\Lib\site-packages\vnstock\trading.py:52, in stock_ls_analysis(symbol_ls, lang)
#      50 df = df.T
#      51 # set ticker row as column name then drop ticker row
# ---> 52 df.columns = df.iloc[0]
#      53 df = df.drop(df.index[0])
#      54 return df
#
# File D:\PyProjects\Anaconda\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File D:\PyProjects\Anaconda\Lib\site-packages\pandas\core\indexing.py:1714, in _iLocIndexer._getitem_axis(self, key, axis)
#    1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
# -> 1714 self._validate_integer(key, axis)
#    1716 return self.obj._ixs(key, axis=axis)
#
# File D:\PyProjects\Anaconda\Lib\site-packages\pandas\core\indexing.py:1647, in _iLocIndexer._validate_integer(self, key, axis)
#    1645 len_axis = len(self.obj._get_axis(axis))
#    1646 if key >= len_axis or key < -len_axis:
# -> 1647     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ### Rating & Evaluation | Xếp hạng và định giá

# %% [markdown]
# #### ⭐General Rating | Xếp hạng chung

# %%
general_rating("CTS")
# Out:
#    stockRating  valuation  financialHealth  businessModel  businessOperation  \
# 0          2.6        1.5              2.0            2.8                3.3
#
#    rsRating  taScore ticker  highestPrice  lowestPrice  priceChange3m  \
# 0       3.4      2.5    CTS       32800.0       8420.0          0.008
#
#    priceChange1y  beta   alpha
# 0          2.147  1.66  0.0175

# %% [markdown]
# #### 🌱 Business Model Rating | Xếp hạng mô hình kinh doanh

# %%
biz_model_rating("CTS")
# Out:
#   ticker  businessModel  businessEfficiency  assetQuality  cashFlowQuality  \
# 0    CTS            2.8                   3             3                3
#
#    bom  businessAdministration  productService  businessAdvantage  \
# 0    3                       3               2                  3
#
#    companyPosition  industry  operationRisk
# 0                2         3              3

# %% [markdown]
# #### 🎮 Business Operation Rating | Xếp hạng hiệu quả hoạt động

# %%
biz_operation_rating("CTS")
# Out:
#             industryEn loanGrowth depositGrowth netInterestIncomeGrowth  \
# 0  Investment Services       None          None                    None
#
#   netInterestMargin costToIncome netIncomeTOI ticker  businessOperation  \
# 0              None         None         None    CTS                3.3
#
#    avgROE  avgROA  last5yearsNetProfitGrowth  last5yearsRevenueGrowth  \
# 0       3       2                          1                        5
#
#    last5yearsOperatingProfitGrowth  last5yearsEBITDAGrowth  \
# 0                                4                       4
#
#    last5yearsFCFFGrowth  lastYearGrossProfitMargin  \
# 0                     2                          5
#
#    lastYearOperatingProfitMargin  lastYearNetProfitMargin TOIGrowth
# 0                              5                        3      None

# %% [markdown]
# #### 📑 Financial Health Rating | Xếp hạng sức khỏe tài chính

# %%
financial_health_rating("VNM")
# Out:
#       industryEn loanDeposit badLoanGrossLoan badLoanAsset provisionBadLoan  \
# 0  Food Products        None             None         None             None
#
#   ticker  financialHealth  netDebtEquity  currentRatio  quickRatio  \
# 0    VNM              4.8              4             5           5
#
#    interestCoverage  netDebtEBITDA
# 0                 5              5

# %% [markdown]
# #### 💲 Valuation Rating | Xếp hạng định giá

# %%
valuation_rating("VNM")
# Out:
#       industryEn ticker  valuation  pe  pb  ps  evebitda  dividendRate
# 0  Food Products    VNM        1.6   2   1   1         1             4

# %% [markdown]
# #### 💳 Industry Financial Health | Xếp hạng Sức khỏe tài chính ngành

# %%
industry_financial_health("VNM")
# Out:
#   industryEn loanDeposit badLoanGrossLoan badLoanAsset provisionBadLoan  \
# 0       None        None             None         None             None
#
#   ticker  financialHealth  netDebtEquity  currentRatio  quickRatio  \
# 0    VNM              3.4              4             3           3
#
#    interestCoverage  netDebtEBITDA
# 0                 3              3

# %% [markdown]
# ## 🔎 Stock Filter | Bộ lọc cổ phiếu

# %%
params = {
            "exchangeName": "HOSE,HNX,UPCOM",
            "marketCap": (100, 1000),
            "dividendYield": (5, 10)
        }

# Áp dụng bộ lọc với hàm để lấy kết quả

df = stock_screening_insights (params, size=1700, drop_lang='vi')
df
# Out:
#    ticker companyName  marketCap   roe  stockRating  businessOperation  \
# 0     AAM                    101   2.1          NaN                2.0
# 1     ABT                    412  13.6          3.3                3.0
# 2     ACL                    614   1.9          2.2                2.7
# 3     BMC                    181   9.6          2.9                2.5
# 4     BTP                    811   3.5          2.4                1.4
# ..    ...         ...        ...   ...          ...                ...
# 72    VRG                    601  15.9          2.6                3.6
# 73    VTB                    106   9.8          NaN                2.6
# 74    VTV                    125   0.6          2.2                1.6
# 75    WSB                    754  11.3          2.6                1.8
# 76    X20                    154   5.7          NaN                1.4
#
#     businessModel  financialHealth  alpha  beta  ...  hasFinancialReport.en  \
# 0             NaN              3.4    0.1   0.5  ...                    Yes
# 1             3.0              4.8    0.6   0.4  ...                    Yes
# 2             3.0              2.4    0.0  -0.7  ...                    Yes
# 3             3.5              4.2    0.2   1.0  ...                    Yes
# 4             3.5              4.8    0.0   0.2  ...                    Yes
# ..            ...              ...    ...   ...  ...                    ...
# 72            3.0              3.6   -1.3  -0.8  ...                    Yes
# 73            NaN              5.0    0.1   0.1  ...                    Yes
# 74            3.5              2.4   -0.6   1.2  ...                    Yes
# 75            2.8              4.2   -0.3   0.1  ...                    Yes
# 76            NaN              4.2    0.5   0.2  ...                    Yes
#
#         priceVsSMA100.en  foreignTransaction.en  uptrend.en  priceVsSMA5.en  \
# 0   Price below SMA(100)                    NaN         NaN             NaN
# 1   Price above SMA(100)                    NaN         NaN             NaN
# 2   Price below SMA(100)             Buy > Sell         NaN             NaN
# 3   Price above SMA(100)             Buy < Sell         NaN             NaN
# 4   Price below SMA(100)             Buy < Sell  Buy Signal             NaN
# ..                   ...                    ...         ...             ...
# 72  Price below SMA(100)                    NaN         NaN             NaN
# 73  Price above SMA(100)                    NaN         NaN             NaN
# 74  Price below SMA(100)                    NaN         NaN             NaN
# 75  Price above SMA(100)             Buy > Sell         NaN             NaN
# 76  Price above SMA(100)                    NaN         NaN             NaN
#
#     bollingBandSignal.en  priceVsSma10.en  sarVsMacdHist.en  tcbsRecommend.en  \
# 0                    NaN              NaN               NaN               NaN
# 1                    NaN              NaN               NaN               NaN
# 2                    NaN              NaN               NaN               NaN
# 3                    NaN              NaN               NaN               NaN
# 4                    NaN              NaN               NaN               NaN
# ..                   ...              ...               ...               ...
# 72                   NaN              NaN       Sell signal               NaN
# 73                   NaN              NaN               NaN               NaN
# 74                   NaN              NaN               NaN               NaN
# 75                   NaN              NaN               NaN               NaN
# 76                   NaN              NaN               NaN               NaN
#
#     heatingUp.en
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 72           NaN
# 73           NaN
# 74           NaN
# 75           NaN
# 76           NaN
#
# [77 rows x 80 columns]

# %% [markdown]
# ## 2.5. 🧰 Trading Center | Dữ liệu giao dịch

# %% [markdown]
# #### 🔥 Intraday Trading Data | Dữ liệu giao dịch trong ngày

# %%
stock_intraday_data(symbol='CTS', page_size=10, investor_segment=False)
# Out:
#   ticker      time orderType  volume    price  prevPriceChange
# 0    CTS  14:45:00            150000  27000.0            250.0
# 1    CTS  14:29:41        SD    5000  26750.0              0.0
# 2    CTS  14:29:41        SD   20600  26750.0              0.0
# 3    CTS  14:29:36        BU    3000  26750.0             50.0
# 4    CTS  14:29:32        SD    3100  26700.0              0.0
# 5    CTS  14:29:29        SD    1900  26700.0            -50.0
# 6    CTS  14:29:28        BU    1000  26750.0             50.0
# 7    CTS  14:29:26        SD    2000  26700.0              0.0
# 8    CTS  14:29:23        SD     500  26700.0            -50.0
# 9    CTS  14:29:23        BU    1000  26750.0             50.0

# %%
stock_intraday_data(symbol='CTS', page_size=10, investor_segment=True)
# Out:
#   ticker      time  orderType investorType  volume  averagePrice  orderCount  \
# 0    CTS  14:29:42  Sell Down         WOLF   25600       26750.0           2
# 1    CTS  14:29:36     Buy Up        SHEEP    3000       26750.0           1
# 2    CTS  14:29:33  Sell Down        SHEEP    3100       26700.0           1
# 3    CTS  14:29:30  Sell Down        SHEEP    1900       26700.0           1
# 4    CTS  14:29:28     Buy Up        SHEEP    1000       26750.0           1
# 5    CTS  14:29:26  Sell Down        SHEEP    2000       26700.0           1
# 6    CTS  14:29:24  Sell Down        SHEEP     500       26700.0           1
# 7    CTS  14:29:23     Buy Up        SHEEP    1000       26750.0           1
# 8    CTS  14:29:23  Sell Down        SHEEP    3100       26700.0           1
# 9    CTS  14:29:17     Buy Up        SHEEP    1900       26700.0           2
#
#    prevPriceChange
# 0              0.0
# 1             50.0
# 2              0.0
# 3            -50.0
# 4             50.0
# 5              0.0
# 6            -50.0
# 7             50.0
# 8              0.0
# 9              0.0

# %% [markdown]
# ## 2.6. 🛡 Derivatives | Phái sinh

# %% [markdown]
# ### Derivative matched data | Khớp lệnh phái sinh

# %%
# Visit `https://livedragon.vdsc.com.vn/all/all.rv`, open `Developer Tools` (F12 or Ctrl + Shift + I) > Navigate to `Network` tab > Choose `Fetch/XHR` > Choose any requests in this tab, find in `Header` > Find `Cookie` > Copy value

cookie = 'YOUR COOKIE VALUE HERE'
derivatives_historical_match (symbol='VN30F2308', date='2023-07-24', cookie=cookie)

# %% [markdown]
# ## 2.7. Chuyển động thị trường

# %% [markdown]
# ### Bản đồ nhiệt giá

# %%
fr_trade_heatmap (symbol='HOSE', report_type='FrBuyVal')
# Out:
#        stockNo  avgPrice  best1Bid  best1BidVol  best2Bid  best2BidVol  \
# 0      hose:21   8959.43      9030        87800      9000        16000
# 1       hose:9   9235.71      9310          100      9300         1000
# 2     hose:702   4940.81      4960         5700      4950        15000
# 3    hose:4413  13843.59     13650         1000     13600          100
# 4     hose:234   5496.04      5550         3800      5540         1100
# ..         ...       ...       ...          ...       ...          ...
# 393  hose:3839  18632.61     18500         1000     18450         2600
# 394  hose:3810   9630.00      9600          300      9250          100
# 395  hose:3814   9110.83      9100        12100      9090         4100
# 396    hose:47   8411.54      8360          100      8350         5000
# 397    hose:34  17654.94     17500         2700     17450         6300
#
#      best3Bid  best3BidVol  ceiling corporateEvents  ... oddSession session  \
# 0        8990         5300     9660              []  ...        PRE     PRE
# 1        9210         2500    10350              []  ...        PRE     PRE
# 2        4940         6400     5280              []  ...        PRE     PRE
# 3       13500         5500    14850              []  ...        PRE     PRE
# 4        5530          700     5930              []  ...        PRE     PRE
# ..        ...          ...      ...             ...  ...        ...     ...
# 393         0            0    21150              []  ...        PRE     PRE
# 394      9240          100    10500              []  ...        PRE     PRE
# 395      9080         5200     9640              []  ...        PRE     PRE
# 396      8300         2100     8930              []  ...        PRE     PRE
# 397     17400         5100    18450              []  ...        PRE     PRE
#
#     matchedVolume  priceChangePercent priceChange  lastMatchedPrice  \
# 0            3720                0.11          10            9050.0
# 1              10                0.00           0            9700.0
# 2            1250                1.01          50            4980.0
# 3              20               -1.44        -200           13700.0
# 4             820                0.00           0            5570.0
# ..            ...                 ...         ...               ...
# 393            10               -0.76        -150           19650.0
# 394            20                0.00           0            9600.0
# 395            20                1.33         120            9110.0
# 396            10                6.59         550            8900.0
# 397          2710                1.45         250           17950.0
#
#      lastMatchedVolume lastPriceChange  lastPriceChangePercent  \
# 0                 10.0            20.0                    0.22
# 1                 10.0             0.0                    0.00
# 2                 50.0            40.0                    0.81
# 3                 20.0          -200.0                   -1.44
# 4                 10.0            20.0                    0.36
# ..                 ...             ...                     ...
# 393               10.0          -150.0                   -0.76
# 394               20.0          -240.0                   -2.44
# 395               30.0           100.0                    1.11
# 396               10.0           550.0                    6.59
# 397               10.0           700.0                    4.06
#
#     nmTotalTradedQty
# 0          1887000.0
# 1             2800.0
# 2           241600.0
# 3             3900.0
# 4           514400.0
# ..               ...
# 393           2300.0
# 394           1600.0
# 395          76300.0
# 396           1300.0
# 397         604900.0
#
# [398 rows x 55 columns]

# %% [markdown]
# ### Top cổ phiếu

# %%
market_top_mover (report_name='Value', exchange='All', filter= 'NetBuyVol', report_range='ThreeMonths', rate='OnePointFive', lang='vi').head()
# Out:
#   organCode ticker             sectorName         value      volume    price  \
# 0       SSI    SSI   Môi giới chứng khoán  6.578055e+11  21401318.0  31400.0
# 1       VIX    VIX   Môi giới chứng khoán  5.648196e+11  35577979.0  16250.0
# 2       VND    VND   Môi giới chứng khoán  5.388330e+11  26429176.0  20800.0
# 3       HPG    HPG  Thép và sản phẩm thép  4.980064e+11  18870086.0  26700.0
# 4  NOVALAND    NVL           Bất động sản  4.830700e+11  28257219.0  17450.0
#
#    floorPrice  ceilingPrice  referencePrice        o        h        l  \
# 0     28850.0       33150.0         31000.0  31000.0  31500.0  30200.0
# 1     15000.0       17200.0         16100.0  16100.0  16300.0  15500.0
# 2     19200.0       22000.0         20600.0  20600.0  20850.0  19900.0
# 3     24500.0       28100.0         26300.0  26400.0  26700.0  26050.0
# 4     16150.0       18550.0         17350.0  17350.0  17450.0  16800.0
#
#    priceChange  percentPriceChange  rank  totalRank  \
# 0        400.0            0.012903     2         43
# 1        150.0            0.009317     6         43
# 2        200.0            0.009709     4         43
# 3        400.0            0.015209     2         47
# 4        100.0            0.005764    29        128
#
#                                          performance  \
# 0  {'organCode': 'SSI', 'percentPriceChange1Day':...
# 1  {'organCode': 'VIX', 'percentPriceChange1Day':...
# 2  {'organCode': 'VND', 'percentPriceChange1Day':...
# 3  {'organCode': 'HPG', 'percentPriceChange1Day':...
# 4  {'organCode': 'NOVALAND', 'percentPriceChange1...
#
#                                            financial  \
# 0  {'organCode': 'SSI', 'rtd7': 15052.6730230217,...
# 1  {'organCode': 'VIX', 'rtd7': 12903.6440468195,...
# 2  {'organCode': 'VND', 'rtd7': 12907.1236382927,...
# 3  {'organCode': 'HPG', 'rtd7': 17161.9648498312,...
# 4  {'organCode': 'NOVALAND', 'rtd7': 18768.114799...
#
#                                            technical
# 0  {'organCode': 'SSI', 'sma20Past4': 30122.5, 's...
# 1  {'organCode': 'VIX', 'sma20Past4': 14902.5, 's...
# 2  {'organCode': 'VND', 'sma20Past4': 19430.0, 's...
# 3  {'organCode': 'HPG', 'sma20Past4': 25697.5, 's...
# 4  {'organCode': 'NOVALAND', 'sma20Past4': 15095....

# %%
market_top_mover (report_name='Losers', exchange='All', filter= 'NetBuyVol', report_range='ThreeMonths', rate='OnePointFive', lang='vi').head()
# Out:
#   organCode ticker                       sectorName         value   volume  \
# 0       HU4    HU4                         Xây dựng  1.028820e+09  74000.0
# 1       TFC    TFC                        Thực phẩm  2.267200e+08  29700.0
# 2    TRACO1    TR1    Kho bãi, hậu cần và bảo dưỡng  2.516800e+08  24200.0
# 3     VGTND    NDT                     Hàng May mặc  8.514000e+07  14100.0
# 4    TNBOOK    STH  Sách, ấn bản & sản phẩm văn hóa  1.607400e+08  12700.0
#
#      price  floorPrice  ceilingPrice  referencePrice        o        h  \
# 0  13900.0     12900.0       17300.0         15100.0  14400.0  14400.0
# 1   7600.0      7500.0        9100.0          8300.0   7800.0   8100.0
# 2  10400.0     10400.0       14000.0         12200.0  10400.0  10400.0
# 3   6600.0      5700.0        7500.0          6600.0   6800.0   6800.0
# 4  14000.0     11900.0       16100.0         14000.0  13000.0  14000.0
#
#          l  priceChange  percentPriceChange  rank  totalRank  \
# 0  13600.0      -1200.0           -0.079000   130        344
# 1   7600.0       -700.0           -0.084337    68        109
# 2  10400.0      -1800.0           -0.148000    98        110
# 3   5700.0       -600.0           -0.085000    14         60
# 4  12500.0      -1300.0           -0.096000    19         41
#
#                                          performance  \
# 0  {'organCode': 'HU4', 'percentPriceChange1Day':...
# 1  {'organCode': 'TFC', 'percentPriceChange1Day':...
# 2  {'organCode': 'TRACO1', 'percentPriceChange1Da...
# 3  {'organCode': 'VGTND', 'percentPriceChange1Day...
# 4  {'organCode': 'TNBOOK', 'percentPriceChange1Da...
#
#                                            financial  \
# 0  {'organCode': 'HU4', 'rtd7': 12756.1917592667,...
# 1  {'organCode': 'TFC', 'rtd7': 14441.3000989781,...
# 2  {'organCode': 'TRACO1', 'rtd7': 22029.48554574...
# 3  {'organCode': 'VGTND', 'rtd7': 11306.829345646...
# 4  {'organCode': 'TNBOOK', 'rtd7': 10205.93319179...
#
#                                            technical
# 0  {'organCode': 'HU4', 'sma20Past4': 12666.25, '...
# 1  {'organCode': 'TFC', 'sma20Past4': 7624.8895, ...
# 2  {'organCode': 'TRACO1', 'sma20Past4': 11977.5,...
# 3  {'organCode': 'VGTND', 'sma20Past4': 6339.15, ...
# 4  {'organCode': 'TNBOOK', 'sma20Past4': 13957.9,...

# %%
market_top_mover (report_name='Gainers', exchange='All', filter= 'NetBuyVol', report_range='ThreeMonths', rate='OnePointFive', lang='vi').head()
# Out:
#   organCode ticker                    sectorName         value    volume  \
# 0     10659    HSV         Thép và sản phẩm thép  4.557420e+09  672800.0
# 1       TIE    TIE           Hàng điện & điện tử  4.966400e+08   71400.0
# 2       VFC    VFC                  Vận tải Thủy  1.750770e+09   19700.0
# 3       HAT    HAT                  Sản xuất bia  2.577400e+08    6900.0
# 4       VHH    VHH  Vật liệu xây dựng & Nội thất  2.588000e+07    6700.0
#
#      price  floorPrice  ceilingPrice  referencePrice        o        h  \
# 0   6800.0      5200.0        7000.0          6100.0   6700.0   6900.0
# 1   7000.0      5200.0        7000.0          6100.0   5900.0   7000.0
# 2  66700.0     66600.0       90000.0         78300.0  80900.0  89900.0
# 3  37400.0     30600.0       37400.0         34000.0  37300.0  37400.0
# 4   3800.0      2900.0        3900.0          3400.0   3800.0   3900.0
#
#          l  priceChange  percentPriceChange  rank  totalRank  \
# 0   6200.0        700.0               0.110    34         47
# 1   5900.0        900.0               0.140    21         24
# 2  66600.0      10600.0               0.135    33        110
# 3  37300.0       3400.0               0.100    16         45
# 4   3800.0        500.0               0.136   274        344
#
#                                          performance  \
# 0  {'organCode': '10659', 'percentPriceChange1Day...
# 1  {'organCode': 'TIE', 'percentPriceChange1Day':...
# 2  {'organCode': 'VFC', 'percentPriceChange1Day':...
# 3  {'organCode': 'HAT', 'percentPriceChange1Day':...
# 4  {'organCode': 'VHH', 'percentPriceChange1Day':...
#
#                                            financial  \
# 0  {'organCode': '10659', 'rtd7': 10719.491571933...
# 1  {'organCode': 'TIE', 'rtd7': 15148.312933364, ...
# 2  {'organCode': 'VFC', 'rtd7': 19815.2627171892,...
# 3  {'organCode': 'HAT', 'rtd7': 21206.3191255203,...
# 4  {'organCode': 'VHH', 'rtd7': 3110.8205504, 'rt...
#
#                                            technical
# 0  {'organCode': '10659', 'sma20Past4': 4406.0, '...
# 1  {'organCode': 'TIE', 'sma20Past4': 5221.5, 'sm...
# 2  {'organCode': 'VFC', 'sma20Past4': 65985.1, 's...
# 3  {'organCode': 'HAT', 'sma20Past4': 35205.0, 's...
# 4  {'organCode': 'VHH', 'sma20Past4': 3315.75, 's...

# %%
market_top_mover (report_name='Volume', exchange='All', filter= 'NetBuyVol', report_range='ThreeMonths', rate='OnePointFive', lang='vi').head()
# Out:
#   organCode ticker          sectorName         value      volume    price  \
# 0       VIX    VIX   Dịch vụ tài chính  5.648196e+11  35577979.0  16250.0
# 1  NOVALAND    NVL        Bất động sản  4.830700e+11  28257219.0  17450.0
# 2       VND    VND   Dịch vụ tài chính  5.388330e+11  26429176.0  20800.0
# 3       SSI    SSI   Dịch vụ tài chính  6.578055e+11  21401318.0  31400.0
# 4       HAG    HAG  Sản xuất thực phẩm  2.138428e+11  20232179.0  10700.0
#
#    floorPrice  ceilingPrice  referencePrice        o        h        l  \
# 0     15000.0       17200.0         16100.0  16100.0  16300.0  15500.0
# 1     16150.0       18550.0         17350.0  17350.0  17450.0  16800.0
# 2     19200.0       22000.0         20600.0  20600.0  20850.0  19900.0
# 3     28850.0       33150.0         31000.0  31000.0  31500.0  30200.0
# 4      9860.0       11300.0         10600.0  10600.0  10750.0  10400.0
#
#    priceChange  percentPriceChange  rank  totalRank  \
# 0        150.0            0.009317     6         43
# 1        100.0            0.005764    29        128
# 2        200.0            0.009709     4         43
# 3        400.0            0.012903     2         43
# 4        100.0            0.009434    10        109
#
#                                          performance  \
# 0  {'organCode': 'VIX', 'percentPriceChange1Day':...
# 1  {'organCode': 'NOVALAND', 'percentPriceChange1...
# 2  {'organCode': 'VND', 'percentPriceChange1Day':...
# 3  {'organCode': 'SSI', 'percentPriceChange1Day':...
# 4  {'organCode': 'HAG', 'percentPriceChange1Day':...
#
#                                            financial  \
# 0  {'organCode': 'VIX', 'rtd7': 12903.6440468195,...
# 1  {'organCode': 'NOVALAND', 'rtd7': 18768.114799...
# 2  {'organCode': 'VND', 'rtd7': 12907.1236382927,...
# 3  {'organCode': 'SSI', 'rtd7': 15052.6730230217,...
# 4  {'organCode': 'HAG', 'rtd7': 5746.1662292443, ...
#
#                                            technical
# 0  {'organCode': 'VIX', 'sma20Past4': 14902.5, 's...
# 1  {'organCode': 'NOVALAND', 'sma20Past4': 15095....
# 2  {'organCode': 'VND', 'sma20Past4': 19430.0, 's...
# 3  {'organCode': 'SSI', 'sma20Past4': 30122.5, 's...
# 4  {'organCode': 'HAG', 'sma20Past4': 8700.5, 'sm...

# %%
market_top_mover (report_name='ForeignTrading', exchange='All', filter= 'NetBuyVol', report_range='ThreeMonths', rate='OnePointFive', lang='vi').head()
# Out:
#    foreignBuyVolume  foreignBuyValue  foreignSellVolume  foreignSellValue  \
# 0         1895550.0     5.418827e+10           166400.0      4.714825e+09
# 1         1081617.0     9.255328e+10            31800.0      2.701120e+09
# 2         1258500.0     3.181841e+10           426200.0      1.079060e+10
# 3          914015.0     3.743836e+10           142800.0      5.886130e+09
# 4          756200.0     2.139864e+10            65000.0      1.851700e+09
#
#   organCode ticker                                   sectorName         value  \
# 0       STB    STB                                    Ngân hàng  7.024270e+11
# 1       DGC    DGC  Sản phẩm hóa dầu, Nông dược & Hóa chất khác  3.008540e+11
# 2       PVD    PVD                  Thiết bị và Dịch vụ Dầu khí  2.013050e+11
# 3       MWG    MWG                   Phân phối hàng chuyên dụng  3.377230e+11
# 4       DCM    DCM  Sản phẩm hóa dầu, Nông dược & Hóa chất khác  1.378230e+11
#
#        volume    price  ...        o        h        l  priceChange  \
# 0  24724100.0  28000.0  ...  29000.0  29200.0  27800.0      -1550.0
# 1   3536100.0  85300.0  ...  87500.0  87900.0  83500.0      -4000.0
# 2   7934400.0  25300.0  ...  26150.0  26300.0  25150.0      -1700.0
# 3   8209600.0  41350.0  ...  42200.0  42400.0  40500.0      -2150.0
# 4   4857700.0  28500.0  ...  29400.0  29500.0  27900.0      -1450.0
#
#    percentPriceChange  rank  totalRank  \
# 0             -0.0525     6         27
# 1             -0.0448     5         72
# 2             -0.0630     2          9
# 3             -0.0494     1         28
# 4             -0.0484     2         72
#
#                                          performance  \
# 0  {'organCode': 'STB', 'percentPriceChange1Day':...
# 1  {'organCode': 'DGC', 'percentPriceChange1Day':...
# 2  {'organCode': 'PVD', 'percentPriceChange1Day':...
# 3  {'organCode': 'MWG', 'percentPriceChange1Day':...
# 4  {'organCode': 'DCM', 'percentPriceChange1Day':...
#
#                                            financial  \
# 0  {'organCode': 'STB', 'rtd7': 22168.8232520548,...
# 1  {'organCode': 'DGC', 'rtd7': 31938.3104643075,...
# 2  {'organCode': 'PVD', 'rtd7': 25278.0709811912,...
# 3  {'organCode': 'MWG', 'rtd7': 15875.60064274, '...
# 4  {'organCode': 'DCM', 'rtd7': 18014.9335876124,...
#
#                                            technical
# 0  {'organCode': 'STB', 'sma20Past4': 30820.0, 's...
# 1  {'organCode': 'DGC', 'sma20Past4': 94020.0, 's...
# 2  {'organCode': 'PVD', 'sma20Past4': 26325.0, 's...
# 3  {'organCode': 'MWG', 'sma20Past4': 49210.0, 's...
# 4  {'organCode': 'DCM', 'sma20Past4': 34355.0, 's...
#
# [5 rows x 23 columns]

# %%
market_top_mover (report_name='NewLow', exchange='All', filter= 'NetBuyVol', report_range='ThreeMonths', rate='OnePointFive', lang='vi').head()
# Out:
#     oldLow organCode ticker                  sectorName         value  \
# 0  18350.0       VND    VND        Môi giới chứng khoán  6.317570e+11
# 1  41750.0       MWG    MWG  Phân phối hàng chuyên dụng  3.377230e+11
# 2  28700.0       KBC    KBC                Bất động sản  2.332400e+11
# 3  20000.0       HUT    HUT                    Xây dựng  1.545196e+11
# 4  17500.0       MBB    MBB                   Ngân hàng  1.336690e+11
#
#        volume    price  floorPrice  ceilingPrice  referencePrice        o  \
# 0  34243600.0  18300.0     18300.0       21000.0         19650.0  19000.0
# 1   8209600.0  41350.0     40500.0       46500.0         43500.0  42200.0
# 2   8077900.0  28650.0     28550.0       32750.0         30650.0  29700.0
# 3   7980100.0  19100.0     19000.0       23200.0         21100.0  21000.0
# 4   7713800.0  17250.0     16600.0       19000.0         17800.0  17650.0
#
#          h        l  priceChange  percentPriceChange  rank  totalRank  \
# 0  19400.0  18300.0      -1350.0             -0.0687     2         43
# 1  42400.0  40500.0      -2150.0             -0.0494     1         28
# 2  29900.0  28550.0      -2000.0             -0.0653    14        128
# 3  21000.0  19000.0      -2000.0             -0.0948    19        346
# 4  17650.0  17100.0       -550.0             -0.0309     5         27
#
#                                          performance  \
# 0  {'organCode': 'VND', 'percentPriceChange1Day':...
# 1  {'organCode': 'MWG', 'percentPriceChange1Day':...
# 2  {'organCode': 'KBC', 'percentPriceChange1Day':...
# 3  {'organCode': 'HUT', 'percentPriceChange1Day':...
# 4  {'organCode': 'MBB', 'percentPriceChange1Day':...
#
#                                            financial  \
# 0  {'organCode': 'VND', 'rtd7': 12382.2648630421,...
# 1  {'organCode': 'MWG', 'rtd7': 15875.60064274, '...
# 2  {'organCode': 'KBC', 'rtd7': 23535.5787017131,...
# 3  {'organCode': 'HUT', 'rtd7': 4371.704998663, '...
# 4  {'organCode': 'MBB', 'rtd7': 15759.9214321219,...
#
#                                            technical
# 0  {'organCode': 'VND', 'sma20Past4': 20957.5, 's...
# 1  {'organCode': 'MWG', 'sma20Past4': 49210.0, 's...
# 2  {'organCode': 'KBC', 'sma20Past4': 31727.5, 's...
# 3  {'organCode': 'HUT', 'sma20Past4': 22750.0, 's...
# 4  {'organCode': 'MBB', 'sma20Past4': 18265.0, 's...

# %%
market_top_mover (report_name='NewHigh', exchange='All', filter= 'NetBuyVol', report_range='ThreeMonths', rate='OnePointFive', lang='vi').head()
# Out:
#    oldHigh organCode ticker       sectorName        value  volume    price  \
# 0  32000.0       VAV    VAV             Nước  240360000.0  7700.0  32100.0
# 1   9300.0       TA3    TA3         Xây dựng   56100000.0  5500.0  10200.0
# 2   4500.0       L43    L43  Máy công nghiệp    3370000.0   700.0   4900.0
# 3  32800.0       PMS    PMS  Máy công nghiệp    7140000.0   200.0  35700.0
# 4   9500.0      ACSC    ACS         Xây dựng    1020000.0   100.0  10200.0
#
#    floorPrice  ceilingPrice  referencePrice        o        h        l  \
# 0     27200.0       36800.0         32000.0  31100.0  32200.0  30000.0
# 1      7600.0       10200.0          8900.0  10200.0  10200.0  10200.0
# 2      4100.0        4900.0          4500.0   4400.0   4900.0   4400.0
# 3     29600.0       36000.0         32800.0  35700.0  35700.0  35700.0
# 4      8100.0       10900.0          9500.0  10200.0  10200.0  10200.0
#
#    priceChange  percentPriceChange  rank  totalRank  \
# 0        100.0              0.0030    38         99
# 1       1300.0              0.1460   289        346
# 2        400.0              0.0889    21         43
# 3       2900.0              0.0884     8         43
# 4        700.0              0.0780   253        346
#
#                                          performance  \
# 0  {'organCode': 'VAV', 'percentPriceChange1Day':...
# 1  {'organCode': 'TA3', 'percentPriceChange1Day':...
# 2  {'organCode': 'L43', 'percentPriceChange1Day':...
# 3  {'organCode': 'PMS', 'percentPriceChange1Day':...
# 4  {'organCode': 'ACSC', 'percentPriceChange1Day'...
#
#                                            financial  \
# 0  {'organCode': 'VAV', 'rtd7': 15073.3706780313,...
# 1  {'organCode': 'TA3', 'rtd7': 13300.4012830814,...
# 2  {'organCode': 'L43', 'rtd7': 5706.8876502857, ...
# 3  {'organCode': 'PMS', 'rtd7': 22386.8284865169,...
# 4  {'organCode': 'ACSC', 'rtd7': 18073.789478, 'r...
#
#                                            technical
# 0  {'organCode': 'VAV', 'sma20Past4': 28520.6, 's...
# 1  {'organCode': 'TA3', 'sma20Past4': 7850.0, 'sm...
# 2  {'organCode': 'L43', 'sma20Past4': 3970.0, 'sm...
# 3  {'organCode': 'PMS', 'sma20Past4': 26000.0, 's...
# 4  {'organCode': 'ACSC', 'sma20Past4': 6572.5, 's...

# %%
market_top_mover (report_name='Breakout', exchange='All', filter= 'NetBuyVol', report_range='TwoWeeks', rate='OnePointFive', lang='vi').head()
# Out:
#    averageMatchVolume organCode ticker            sectorName         value  \
# 0          24374738.0       SHS    SHS  Môi giới chứng khoán  5.979848e+11
# 1          21766652.0       SSI    SSI  Môi giới chứng khoán  1.028099e+12
# 2          21686740.0       VND    VND  Môi giới chứng khoán  6.317570e+11
# 3          15035396.0       STB    STB             Ngân hàng  7.024270e+11
# 4           4324588.0       EIB    EIB             Ngân hàng  1.440780e+11
#
#        volume    price  floorPrice  ceilingPrice  referencePrice        o  \
# 0  39732100.0  14900.0     14600.0       17800.0         16200.0  16000.0
# 1  35611300.0  28700.0     28650.0       32950.0         30800.0  29700.0
# 2  34243600.0  18300.0     18300.0       21000.0         19650.0  19000.0
# 3  24724100.0  28000.0     27500.0       31600.0         29550.0  29000.0
# 4   8315600.0  17150.0     16850.0       19350.0         18100.0  17800.0
#
#          h        l  priceChange  percentPriceChange  rank  totalRank  \
# 0  16200.0  14600.0      -1300.0             -0.0802     8         43
# 1  29950.0  28650.0      -2100.0             -0.0682     1         43
# 2  19400.0  18300.0      -1350.0             -0.0687     2         43
# 3  29200.0  27800.0      -1550.0             -0.0525     6         27
# 4  17800.0  17100.0       -950.0             -0.0525    16         27
#
#                                          performance  \
# 0  {'organCode': 'SHS', 'percentPriceChange1Day':...
# 1  {'organCode': 'SSI', 'percentPriceChange1Day':...
# 2  {'organCode': 'VND', 'percentPriceChange1Day':...
# 3  {'organCode': 'STB', 'percentPriceChange1Day':...
# 4  {'organCode': 'EIB', 'percentPriceChange1Day':...
#
#                                            financial  \
# 0  {'organCode': 'SHS', 'rtd7': 12434.5093589496,...
# 1  {'organCode': 'SSI', 'rtd7': 15052.6730230217,...
# 2  {'organCode': 'VND', 'rtd7': 12382.2648630421,...
# 3  {'organCode': 'STB', 'rtd7': 22168.8232520548,...
# 4  {'organCode': 'EIB', 'rtd7': 12305.3349188337,...
#
#                                            technical
# 0  {'organCode': 'SHS', 'sma20Past4': 17115.0, 's...
# 1  {'organCode': 'SSI', 'sma20Past4': 32092.5, 's...
# 2  {'organCode': 'VND', 'sma20Past4': 20957.5, 's...
# 3  {'organCode': 'STB', 'sma20Past4': 30820.0, 's...
# 4  {'organCode': 'EIB', 'sma20Past4': 17497.5, 's...

# %% [markdown]
# # III. 📈 Charting | Vẽ đồ thị

# %% [markdown]
# vnstock sử dụng thư viện `plotly` làm thư viện biểu diễn dữ liệu trực quan. Để có thể sử dụng được tính năng vẽ đồ thị, bạn cần đảm bảo `plotly` đã được cài đặt thành công.
# - Câu lệnh cài đặt plotly: `pip install plotly`
# - Hoặc chạy lệnh cài đặt toàn bộ thư viện phụ thuộc: `pip install -r requirements.txt` . Đảm bảo bạn đã cd đến đúng thư mục chứa file [requirements.txt](https://github.com/thinh-vu/vnstock/blob/beta/requirements.txt) trước khi chạy lệnh.

# %% [markdown]
# ## Vẽ đồ thị

# %% [markdown]
# ### Đồ thị nến

# %%
pip install git+https://github.com/thinh-vu/vnstock.git@beta

# %%
from vnstock import * #import all functions, including functions that provide OHLC data for charting
from vnstock.chart import * # import chart functions
df = stock_historical_data("CTS", "2022-01-01", "2023-11-28", "1D", "stock")
fig = candlestick_chart(df, ma_periods=[50,200], show_volume=False, reference_period=300, figure_size=(15, 8),
                        title='VIC - Candlestick Chart with MA and Volume', x_label='Date', y_label='Price',
                        colors=('lightgray', 'gray'), reference_colors=('black', 'blue'))

fig.show()
# Out:
# <div>                            <div id="70ae9d89-a4e8-4046-87dc-a144b7d9e569" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70ae9d89-a4e8-4046-87dc-a144b7d9e569")) {                    Plotly.newPlot(                        "70ae9d89-a4e8-4046-87dc-a144b7d9e569",                        [{"close":[34200,35700,35200,34340,32049,30050,32119,30980,31830,29620,27580,27620,28330,27330,25440,24180,24830,25400,24970,25470,26150,27150,26800,26900,25400,25610,26220,26080,26610,27620,26940,27150,27480,29040,29190,28980,28190,28620,28620,28120,27690,27260,27620,26610,25470,25750,26120,26080,26430,26830,27480,26970,26800,26540,26000,26430,26120,26000,26770,28630,28050,28200,27430,25880,25340,25880,25230,24650,22950,21360,20170,20710,20710,19280,19240,19240,19160,19470,18540,18350,17080,15920,15300,15690,14600,13600,13910,14870,15380,16379,16460,15450,15840,16770,17230,17040,16960,16730,16730,16570,16379,16230,15690,16300,16500,15610,14530,13680,12750,12050,11240,10470,10510,11240,11200,11440,12210,12360,12630,11780,12360,12900,12630,11980,11780,12520,12520,13140,12980,13870,13680,13640,13370,14260,13990,13640,13640,13290,13600,14100,14290,15260,15800,16070,16110,17000,16920,17000,16920,16230,17040,17150,17850,18200,18810,18540,17690,18540,19800,20100,19600,19100,18600,19100,19300,19500,18800,18600,18950,18650,18650,19200,19000,18000,16750,17300,17100,17850,17800,16600,16600,16600,15600,16450,15300,14650,15350,14300,13300,13800,12850,13200,13250,13700,13500,13600,13600,13150,12250,11400,11000,10250,10950,11200,11150,11850,11850,11650,10850,10100,10150,10050,9350,8700,8100,7540,8060,8620,9010,8880,8950,8330,8420,9000,9630,10300,11000,11250,12000,12800,12900,12500,13350,14250,13300,14200,15100,15150,14900,14650,13800,13200,13700,13450,12550,12500,13400,13600,12700,12650,13500,13750,13800,13700,13700,13750,14350,14200,14400,14500,15300,15450,15450,14700,14600,15150,14100,13550,13500,13600,13500,13800,13800,13450,12550,12750,12850,13400,13300,14200,14300,13400,13500,13000,12200,12350,13150,13050,12550,12600,12850,13300,13400,13400,13100,12650,13500,13900,13850,13450,14200,14250,14900,14950,15300,15400,15800,15950,16550,16950,17300,17150,16700,17600,17200,17550,17150,16700,16600,16600,17600,17150,16850,17500,17250,16000,16149,16149,16600,16850,16550,17050,17000,17000,17350,17650,17100,17050,16750,17300,17300,17500,17850,19000,18600,18800,19050,19350,19150,19350,19400,18700,19200,19100,18300,18800,18600,19300,18900,18750,18950,19500,19800,21150,21400,21700,22500,22150,21850,21000,21500,21750,22700,22250,21950,22350,22650,22500,22950,23000,23100,23000,22700,22600,22600,24150,24950,24600,25000,24900,25200,25800,25400,26000,25950,26350,26800,26250,25750,25000,25850,26500,26100,25900,26050,24250,24100,25000,24650,25350,25600,26300,26350,28150,28700,28750,30000,30000,29900,30250,32350,32600,32000,31450,31600,32299,32800,31100,28950,26950,27000,28850,29500,28900,28300,26350,26800,25500,26200,26600,26600,27500,27600,27400,26700,24850,23200,21600,23100,23600,24000,23300,21700,22300,20800,19400,20750,22200,22250,23100,23300,24900,25550,25050,25700,25950,25900,26600,25800,27250,27550,28350,26400,27300,26500,27000],"high":[34200,36560,37060,35590,35130,32409,32119,32990,32270,31760,28470,28540,28910,28400,26540,24900,25720,26470,25680,26190,26430,27580,27620,27190,26830,25680,26430,26470,26800,27830,27400,27510,28050,29330,29690,29260,29040,28620,29510,28470,28830,27970,28400,27620,26690,26190,26330,26400,26690,27040,27510,27690,27190,27330,27350,26660,26970,26660,26770,28630,29360,28590,28550,27620,26540,26660,26270,25610,24420,23180,21710,21250,21630,21170,19470,19320,19900,19700,19630,18930,18040,16880,15920,15760,15450,14760,14530,14870,15840,16420,17000,16610,15840,16770,17580,17390,17390,17150,17150,17310,16690 ...

# %% [markdown]
# Bạn có thể điều chỉnh lại các thông số của hàm cho phù hợp, loại bỏ các thông số không cần thiết khi gọi hàm sẽ cho phép hàm sử dụng giá trị cài đặt mặc định, hoặc bạn điều chỉnh bằng cách cung cấp tham số mới vào. Ngoài ra bạn có thể tương tác trực tiếp với đồ thị, ví dụ click vào thông tin chú thích tương tứng từng loại dữ liệu để bật/tắt chúng mà không cần can thiệp vào dòng lệnh.
#
# Các tham số của hàm bao gồm:
#
# - df : DataFrame chứa dữ liệu giá định dạng OHLC
# - ma_periods: Các dải MA cần tính toán, nhập vào dưới dạng một danh sách. Ví dụ [10, 50, 200] sẽ cho phép tính MA10, MA50, MA200. Bạn có thể nhập bao nhiêu dải MA tùy thích.
# - show_volume: True để hiển thị thông tin khối lượng giao dịch, False để ẩn.
# - reference_period: Số ngày để tính toán đường tham chiếu đỉnh/đáy của giá Ví dụ 90.
# - figure_size: Kích thước đồ thị, nhập dưới dạng tupple ví dụ (15, 8) thể hiện 1500 x 800px.
# - title: Tên của đồ thị.
# - x_label: Nhãn trục x (hoành)
# - y_label: Nhãn trục y (tung)
# - colors: Mã màu thể hiện cho khối lượng giao dịch trong những ngày giá cổ phiếu tăng/giảm, được nhập dưới dạng tupple. Ví dụ ('#00F4B0', '#FF3747').
# - reference_color: Cặp mã màu cho đường hỗ trợ (lowest low), kháng cự (highest high) được nhập vào dưới dạng tupple. Ví dụ ('black', 'blue')

# %%
from vnstock import * #import all functions

df = stock_historical_data(symbol='VNINDEX', start_date='2022-01-01', end_date='2023-11-28', resolution='1D', type='index')
fig = candlestick_chart(df,
                  title='VNINDEX Candlestick Chart with MA and Volume', x_label='Date', y_label='Price', ma_periods=[50,200],
                  show_volume=True, figure_size=(15, 8), reference_period=300,
                  colors=('lightgray', 'gray'), reference_colors=('black', 'blue'))
fig.show()
# Out:
# <div>                            <div id="73172b39-b8f4-4f10-8f2d-c9b6a3813ca8" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73172b39-b8f4-4f10-8f2d-c9b6a3813ca8")) {                    Plotly.newPlot(                        "73172b39-b8f4-4f10-8f2d-c9b6a3813ca8",                        [{"close":[1525.58,1522.5,1528.57,1528.48,1503.71,1492.31,1510.51,1496.05,1496.02,1452.84,1438.94,1442.79,1465.3,1472.89,1439.71,1479.58,1481.58,1470.76,1478.96,1497.66,1500.99,1505.38,1506.79,1501.71,1471.96,1492.75,1492.1,1507.99,1504.84,1510.84,1503.47,1512.3,1494.85,1498.89,1490.13,1498.78,1485.52,1505.0,1505.33,1499.05,1473.71,1473.74,1479.08,1466.54,1446.25,1452.74,1459.33,1461.34,1469.1,1494.95,1503.78,1502.34,1498.26,1498.5,1483.18,1497.76,1490.51,1492.15,1516.44,1524.7,1520.03,1522.9,1502.35,1482.0,1455.25,1477.2,1472.12,1458.56,1432.6,1406.45,1384.72,1370.21,1379.23,1310.92,1341.34,1353.77,1350.99,1366.8,1348.68,1360.68,1329.26,1269.62,1293.56,1301.53,1238.84,1182.77,1171.95,1228.37,1240.76,1241.64,1240.71,1218.81,1233.38,1268.43,1268.57,1285.45,1293.92,1292.68,1299.52,1288.62,1287.98,1290.01,1291.35,1307.91,1307.8,1284.08,1227.04,1230.31,1213.93,1236.63,1217.3,1180.4,1172.47,1169.27,1188.88,1185.48,1202.82,1218.1,1218.09,1197.6,1198.9,1195.53,1181.29,1149.61,1166.48,1171.31,1155.29,1174.82,1173.92,1182.17,1179.25,1176.49,1178.33,1194.14,1198.47,1194.76,1188.5,1185.07,1191.04,1208.12,1206.33,1231.35,1236.12,1249.76,1254.15,1252.74,1256.75,1258.85,1256.5,1252.07,1262.33,1274.2,1274.69,1275.28,1273.66,1269.18,1260.43,1270.81,1277.16,1288.88,1282.57,1270.8,1279.39,1280.51,1277.35,1277.4,1243.17,1234.6,1248.78,1249.62,1248.4,1240.77,1245.66,1234.03,1205.43,1218.93,1210.55,1214.7,1203.28,1174.35,1166.54,1143.62,1126.07,1132.11,1086.44,1078.14,1104.26,1074.52,1035.91,1042.48,1006.2,1034.81,1050.99,1061.85,1051.58,1063.66,1060.07,1058.45,1019.82,986.15,997.7,992.85,1022.16,1028.56,1021.42,1028.41,1021.52,1017.03,994.12,971.22,976.99,981.33,942.65,952.88,941.04,911.9,942.9,969.26,969.33,960.65,952.12,946.0,947.71,971.46,1005.69,1032.16,1048.42,1036.28,1080.01,1093.67,1048.69,1041.02,1050.53,1051.81,1032.07,1047.45,1050.43,1055.32,1052.48,1038.4,1023.13,1018.88,1022.61,1020.34,985.21,1004.57,1015.66,1009.29,1007.09,1043.9,1046.35,1055.82,1051.44,1054.21,1053.35,1055.76,1056.39,1060.17,1066.68,1088.29,1098.28,1108.08,1117.1,1102.57,1111.18,1075.97,1077.59,1077.15,1089.29,1065.84,1072.22,1064.03,1055.3,1043.7,1038.64,1048.2,1058.29,1059.31,1086.69,1082.23,1054.28,1053.66,1039.56,1021.25,1024.68,1040.55,1037.61,1024.77,1027.18,1037.84,1049.18,1055.95,1053.0,1052.8,1040.13,1062.19,1047.4,1045.14,1023.1,1032.43,1040.54,1045.1,1046.79,1052.25,1054.29,1056.33,1059.44,1064.64,1079.28,1078.45,1080.86,1070.91,1065.35,1069.46,1069.45,1064.3,1052.89,1053.81,1055.02,1048.98,1049.25,1042.91,1041.36,1034.85,1040.8,1039.63,1049.12,1040.61,1040.31,1052.62,1053.77,1058.26,1057.12,1066.9,1065.71,1065.91,1060.44,1068.31,1067.07,1070.64,1065.85,1061.79,1064.63,1063.76,1074.98,1078.05,1075.17,1078.39,1090.84,1097.82,1108.31,1109.54,1101.32,1107.53,1116.02,1122.46,1117.42,1116.97,1115.22,1105.4,1111.72,1118.46,1125.3,1129.38,1132.03,1134.33,1138.35,1125.39,1120.18,1125.5,1132.0,1134.62,1126.22,1138.07,1149.02,1151.77,1154.2,1165.42,1168.4,1173.13,1174.09,1172.98,1172.81,1185.9,1190.72,1195.9,1200.84,1197.33,1207.67,1222.9,1217.56,1220.43,1210.95,1225.98,1241.42,1242.23,1233.99,1220.61,1232.21,1236.84,1234.05,1243.26,1233.48,1177.99,1179.76,1180.49,1172.56,1189.39,1183.37,1201.72,1204.43,1213.16,1224.05,1234.98,1245.5,1243.14,1241.48,1223.63,1245.44,1238.39,1223.81,1227.36,1211.81,1211.5,1226.11,1212.74,1193.05,1153.2,1137.96,1153.85,1152.43,1154.15,1155.25,1118.1,1128.67,1113.89,1128.54,1137.36,1143.69,1150.81,1151.61,1154.73, ...

# %% [markdown]
# ### Dải Bollinger Bands

# %%
df = bollinger_bands(df, window=20, num_std_dev=2)
fig = bollinger_bands_chart(df, use_candlestick=True, show_volume=True,
                            fig_size=(15, 8), chart_title='Bollinger Bands Chart', xaxis_title='Date', yaxis_title='Price',
                            bollinger_band_colors=('gray', 'orange', 'gray'), volume_colors=('#00F4B0', '#FF3747'))
fig.show()

# %% [markdown]
# Hàm bollinger_bands cho phép tùy chỉnh các tham số tính toán giá trị để sử dụng trong biểu diễn dữ liệu, các tham số bao gồm:
# - df: DataFrame chứa dữ liệu giá định dạng OHLC, sử dụng hàm stock_historical_data.
# - window: Khung thời gian để tính toán giá trị trung bình động đơn giản (SMA), mặc định là 20 ngày.
# - num_std_dev: Số kỳ tính độ lệch chuẩn. Mặc định là 2.

# %% [markdown]
# Hàm vẽ đồ thị Bollinger Bands bao gồm các tham số:
#
# - df: DataFrame chứa dữ liệu Bollinger Bands ('time', 'open', 'high', 'low', 'close', 'volume', 'ticker', 'upper_band', 'middle_band', 'lower_band'). Dữ liệu này có được sau khi xử lý dữ liệu giá định dạng OHLC (hàm stock_historical_data) với hàm bollinger_bands.
# - use_candlestick: Chọn sử dụng đồ thị nến (giá trị True) hay chỉ biểu diễn giá đóng cửa dạng đồ thị đường (giá trị False). Mặc định dùng đồ thị nến.
# - show_volume: Chọn hiển thị thông tin khối lượng giao dịch (True) hoặc ẩn đi (False). Mặc định hiển thị.
# - fig_size: Tupple chứa giá trị kích thước đồ thị (width, height). Ví dụ (15, 8) thể hiện 1500 x 800px.
# - chart_title: Tên của đồ thị. Nếu không chỉ rõ, sẽ dùng tên mặc định
# - xaxis_title: Tên của trục x (hoành)
# - yaxis_title: Tên của trục y (tung)
# - bollinger_band_colors: Tupple chứa bộ mã màu cho dải Bollinger Bands (upper, middle, lower).
# - volume_colors: Tuple chứa mã màu cho thông tin khối lượng giao dịch trong những ngày giá tăng, giảm. Ví dụ ('green', 'red').

# %% [markdown]
# ## Lưu đồ thị dưới dạng file ảnh

# %% [markdown]
# Để lưu đồ thị với câu lệnh, bạn cần cài đặt gói phụ thuộc `kaleido` sau đó thực hiện lưu file như dưới đây. Sau khi cài đặt thì cần phải khởi động lại runtime của Jupyter Notebook. Trên Google Colab chọn Menu `Runtime` -> `Restart runtime`.
#
# Sau đó bạn cần chạy lại các lệnh để vẽ đồ thị rồi mới có thể lưu. Việc này khá bất tiện, do đó nếu không có nhu cầu lưu file bằng câu lệnh, bạn có thể thực hiện từ giao diện đồ họa của đồ thị, chọn biểu tượng cái máy ảnh (thanh công cụ phía trên bên phải), click vào và chọn thư mục để lưu file.

# %%
# !pip install -U kaleido

# %%
# save candlestick chart to file
fig.write_image(r"D:\OneDrive\Github\vnstock\docs\assets\VNINDEX_candlestick.png")

# %% [markdown]
# # IV. Integration | Tích hợp dịch vụ

# %% [markdown]
# ## Amibroker

# %%
amibroker_ohlc_export (path='', symbol='CTS', start_date='2023-01-01', end_date='2023-11-08', resolution='1D', type='stock', source='DNSE')
# Out:
# Data preview:
#    <Ticker> <DTYYYYMMDD>  <Open>  <High>  <Low>  <Close>  <Volume>
# 0      CTS     20230103   12.65   13.50  12.65    13.50    932800
# 1      CTS     20230104   14.05   14.15  13.75    13.75   1496300
# 2      CTS     20230105   13.80   14.10  13.25    13.80   1044700
# 3      CTS     20230106   14.00   14.35  13.60    13.70   1420200
# 4      CTS     20230109   14.00   14.10  13.70    13.70    773600

# %% [markdown]
# ## DNSE API

# %% [markdown]
# Trước hết, các bạn cần đăng nhập hệ thống và lấy mã JWT token để có thể sử dụng gọi các API tiếp theo của DNSE cho việc tra cứu thông tin và đặt lệnh

# %%
from vnstock.integration import *
USR = 'TÊN_ĐĂNG_NHẬP_DNSE_CỦA_BẠN'
PWD = 'MẬT_KHẨU_DNSE_CỦA_BẠN'

# %% [markdown]
# ### Đăng nhập hệ thống

# %%
client = DNSEClient()
client.login(USR, PWD)

# %% [markdown]
# ### Lấy mã OTP qua email

# %%
client.email_otp()

# %% [markdown]
# ### Xác thực OTP (SmartOTP và email OTP)

# %%
client.get_trading_token(otp='123456', smart_otp=True) # smart_otp = True nếu dùng mã OTP lấy từ app EntradeX, False nếu dùng mã OTP lấy từ email

# %% [markdown]
# ### Lấy thông tin tài khoản

# %%
client.account().T

# %% [markdown]
# ```
# id                                                                0123456789
# investorId                                                        0123456789
# name                                                               Vũ Thịnh
# custodyCode                                                        064C12345
# email                                                   support@vnstock.site
# unverifiedEmail                                         support@vnstock.site
# mobile                                                            0123456789
# status                                                                ACTIVE
# createdDate                                         2023-01-01T00:00:00.007Z
# modifiedDate                                        2023-01-01T00:00:00.007Z
# enId                                        xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxx
# identificationCode                                          0123456789010101
# identificationDate                                      2021-01-01T00:00:00Z
# identificationExpiredDate                               2100-01-01T00:00:00Z
# identificationPlace                                      Cục CS QLHC về TTXH
# birthday                                                XXXX-XX-XXT00:00:00Z
# address                                   vnstock chào đón các nhà đầu tư 😁
# gender                                                                  MALE
# flexCustomerId                                                    000000000
# smartOtpRegistrationId                                               xxxxx
# userApproveType                                                AUTO_APPROVED
# referralCode                                                          xxxxxx
# referralUrl                                         https://s.dnse.vn/xxxxxx
# avatarUrl                           https://lh3.googleusercontent.com/xyzxyz
# needToChangePassword                                                   True
# registeredSmartOtp                                                     False
# isEmailVerified                                                        False
# ```

# %% [markdown]
# ### Lấy thông tin tiểu khoản

# %%
client.sub_accounts().T

# %% [markdown]
# ### Thông tin số dư tiền

# %%
client.account_balance (sub_account='0001213141')

# %% [markdown]
# ### Danh sách gói vay

# %%
client.loan_packages(sub_account='0001213141', asset_type='stock')

# %% [markdown]
# ### Sức mua, sức bán

# %%
client.trade_capacities(symbol='VIC', price=41600, sub_account='0001213141', asset_type='stock', loan_package_id=None)

# %% [markdown]
# ### Đặt lệnh

# %%
client.place_order('0001213141', 'VIC', 'buy', 500, 41600, 'LO', None, 'stock') # thay thế thông tin tương ứng cho phái sinh

# %% [markdown]
# ### Sổ lệnh

# %%
client.order_list(sub_account='0001213141', asset_type='stock')

# %% [markdown]
# ### Chi tiết lệnh

# %%
client.order_detail(order_id='MÃ_LỆNH_CỦA_BẠN', sub_account='MÃ_TIỂU_KHOẢN_CỦA_BẠN', asset_type='stock')

# %% [markdown]
# ### Hủy lệnh

# %%
client.cancel_order (order_id='MÃ_LỆNH_CỦA_BẠN', sub_account='MÃ_TIỂU_KHOẢN_CỦA_BẠN', asset_type='stock')

# %% [markdown]
# ### Deal nắm giữ

# %%
client.deals_list (sub_account='MÃ_TIỂU_KHOẢN_CỦA_BẠN', asset_type='stock')

# %% [markdown]
# # V. 🚚 Data Export | Xuất dữ liệu

# %% [markdown]
# ## DataFrame to Google Sheets | Xuất dữ liệu sang Google Sheets
#
# Dưới đây là cách xuất dữ liệu đơn giản qua Google Sheets, không cần cài đặt thêm thư viện nào nếu sử dụng Google Colab. Không áp dụng với các môi trường khác
#
# This following code apply for export data to Google Sheets from Google Colab only. If you run this code in local machine, it will not work.

# %%
df = listing_companies() # Gán bất cứ hàm nào cho 1 biến để xuất dữ liệu, ví dụ ở đây là listing_companies
sheet_file = 'listing_companies' # Đặt tên cho file Google Sheets sẽ tạo (nếu tạo mới, dùng file có sẵn thì không cần)

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
from gspread_dataframe import set_with_dataframe

creds, _ = default()
gc = gspread.authorize(creds)from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
from gspread_dataframe import set_with_dataframe

creds, _ = default()
gc = gspread.authorize(creds)

# %% [markdown]
# ### Update an entire worksheet with a DataFrame.

# %%
sh = gc.create(sheet_file)
worksheet = gc.open(sheet_file).sheet1 # Mở sheet mặc định để xuất dữ liệu, chọn 1 trong 3 tùy chọn với biến worksheet, dùng dòng nào bỏ comment dòng đó, và comment dòng không cần dùng
# worksheet = sh.add_worksheet(title="listing_companies", rows="1000", cols="20") # Tạo sheet mới để xuất dữ liệu
# worksheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1vT6o6U1dHYMdHASZNKPvmzDRhgKTvQXsZ_46CvBOpuI').sheet1  # Mở file sheet có sẵn bằng URL
set_with_dataframe(worksheet, df)

# %% [markdown]
# ### Update a cell range with a DataFrame

# %%
worksheet = gc.open(sheet_file).sheet1 # Mở sheet mặc định để xuất dữ liệu, chọn 1 trong 3 tùy chọn với biến worksheet, dùng dòng nào bỏ comment dòng đó, và comment dòng không cần dùng

cell_list = worksheet.range('A1:C2') # Chọn vùng dữ liệu trên Google Sheets bạn muốn chèn dữ liệu từ DataFrame
# Update the data in the worksheet

for cell, value in zip(cell_list, df.values.flatten()):
    cell.value = value

worksheet.update_cells(cell_list)
